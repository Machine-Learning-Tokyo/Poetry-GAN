# %%
from fastai.text import *

# %%
PATH = Path('data')
POEMS = PATH/'poems.txt'
WIKI = PATH/'wikitext-103/wiki.train.tokens'

# %%
poems = POEMS.open().read().split('\n\n\n\n\n\n\n')
poems = [poem.strip().replace('\n','') for poem in poems]
wiki = WIKI.open().read().split('\n')
wiki = [sent.strip() for sent in wiki if len(sent) > 2000]

# %%
len(poems), poems[:3], len(wiki)
# Out:
# (746,
#  ["O Captain! my Captain! our fearful trip is done;The ship has weather'd every rack, the prize we sought is won;The port is near, the bells I hear, the people all exulting,While follow eyes the steady keel, the vessel grim and daring:But O heart! heart! heart!O the bleeding drops of red,Where on the deck my Captain lies,Fallen cold and dead.O Captain! my Captain! rise up and hear the bells;Rise up--for you the flag is flung--for you the bugle trills; 10For you bouquets and ribbon'd wreaths--for you the shores a-crowding;For you they call, the swaying mass, their eager faces turning;Here Captain! dear father!This arm beneath your head;It is some dream that on the deck,You've fallen cold and dead.My Captain does not answer, his lips are pale and still;My father does not feel my arm, he has no pulse nor will;The ship is anchor'd safe and sound, its voyage closed and done;From fearful trip, the victor ship, comes in with object won; 20Exult, O shores, and ring, O bells!But I, with mournful tread,Walk the deck my Captain lies,Fallen cold and dead.",
#   'This is thy hour O Soul, thy free flight into the wordless,Away from books, away from art, the day erased, the lesson done,Thee fully forth emerging, silent, gazing, pondering the themes thoulovest best.Night, sleep, death and the stars.',
#   'This is thy hour O Soul, thy free flight into the wordless,Away from books, away from art, the day erased, the lesson done,Thee fully forth emerging, silent, gazing, pondering the themes thoulovest best.Night, sleep, death and the stars.'],
#  4221)

# %%
tok_poems = Tokenizer.proc_all(poems, 'en')
tok_wiki = Tokenizer.proc_all(wiki, 'en')

# %%
tok_poems[:2]
# Out:
# [['o',
#   'captain',
#   '!',
#   'my',
#   'captain',
#   '!',
#   'our',
#   'fearful',
#   'trip',
#   'is',
#   'done;the',
#   'ship',
#   'has',
#   "weather'd",
#   'every',
#   'rack',
#   ',',
#   'the',
#   'prize',
#   'we',
#   'sought',
#   'is',
#   'won;the',
#   'port',
#   'is',
#   'near',
#   ',',
#   'the',
#   'bells',
#   'i',
#   'hear',
#   ',',
#   'the',
#   'people',
#   'all',
#   'exulting',
#   ',',
#   'while',
#   'follow',
#   'eyes',
#   'the',
#   'steady',
#   'keel',
#   ',',
#   'the',
#   'vessel',
#   'grim',
#   'and',
#   'daring',
#   ':',
#   'but',
#   'o',
#   'heart',
#   '!',
#   'heart',
#   '!',
#   'heart!o',
#   'the',
#   'bleeding',
#   'drops',
#   'of',
#   'red',
#   ',',
#   'where',
#   'on',
#   'the',
#   'deck',
#   'my',
#   'captain',
#   'lies',
#   ',',
#   'fallen',
#   'cold',
#   'and',
#   'dead.o',
#   'captain',
#   '!',
#   'my',
#   'captain',
#   '!',
#   'rise',
#   'up',
#   'and',
#   'hear',
#   'the',
#   'bells;rise',
#   'up',
#   '--',
#   'for',
#   'you',
#   'the',
#   'flag',
#   'is',
#   'flung',
#   '--',
#   'for',
#   'you',
#   'the',
#   'bugle',
#   'trills',
#   ';',
#   '10for',
#   'you',
#   'bouquets',
#   'and',
#   "ribbon'd",
#   'wreaths',
#   '--',
#   'for',
#   'you',
#   'the',
#   'shores',
#   'a',
#   '-',
#   'crowding;for',
#   'you',
#   'they',
#   'call',
#   ',',
#   'the',
#   'swaying',
#   'mass',
#   ',',
#   'their',
#   'eager',
#   'faces',
#   'turning;here',
#   'captain',
#   '!',
#   'dear',
#   'father!this',
#   'arm',
#   'beneath',
#   'your',
#   'head;it',
#   'is',
#   'some',
#   'dream',
#   'that',
#   'on',
#   'the',
#   'deck',
#   ',',
#   "you've",
#   'fallen',
#   'cold',
#   'and',
#   'dead.my',
#   'captain',
#   'does',
#   'not',
#   'answer',
#   ',',
#   'his',
#   'lips',
#   'are',
#   'pale',
#   'and',
#   'still;my',
#   'father',
#   'does',
#   'not',
#   'feel',
#   'my',
#   'arm',
#   ',',
#   'he',
#   'has',
#   'no',
#   'pulse',
#   'nor',
#   'will;the',
#   'ship',
#   'is',
#   "anchor'd",
#   'safe',
#   'and',
#   'sound',
#   ',',
#   'its',
#   'voyage',
#   'closed',
#   'and',
#   'done;from',
#   'fearful',
#   'trip',
#   ',',
#   'the',
#   'victor',
#   'ship',
#   ',',
#   'comes',
#   'in',
#   'with',
#   'object',
#   'won',
#   ';',
#   '20exult',
#   ',',
#   'o',
#   'shores',
#   ',',
#   'and',
#   'ring',
#   ',',
#   'o',
#   'bells!but',
#   'i',
#   ',',
#   'with',
#   'mournful',
#   'tread',
#   ',',
#   'walk',
#   'the',
#   'deck',
#   'my',
#   'captain',
#   'lies',
#   ',',
#   'fallen',
#   'cold',
#   'and',
#   'dead',
#   '.'],
#  ['this',
#   'is',
#   'thy',
#   'hour',
#   'o',
#   'soul',
#   ',',
#   'thy',
#   'free',
#   'flight',
#   'into',
#   'the',
#   'wordless',
#   ',',
#   'away',
#   'from',
#   'books',
#   ',',
#   'away',
#   'from',
#   'art',
#   ',',
#   'the',
#   'day',
#   'erased',
#   ',',
#   'the',
#   'lesson',
#   'done',
#   ',',
#   'thee',
#   'fully',
#   'forth',
#   'emerging',
#   ',',
#   'silent',
#   ',',
#   'gazing',
#   ',',
#   'pondering',
#   'the',
#   'themes',
#   'thoulovest',
#   'best.night',
#   ',',
#   'sleep',
#   ',',
#   'death',
#   'and',
#   'the',
#   'stars',
#   '.']]

# %%
trn_poems,val_poems = sklearn.model_selection.train_test_split(tok_poems, test_size=0.2)
trn_wiki,val_wiki = sklearn.model_selection.train_test_split(tok_wiki, test_size=0.2)

pickle.dump(trn_poems, open(PATH/'trn_poems_en.pkl', 'wb'))
pickle.dump(val_poems, open(PATH/'val_poems_en.pkl', 'wb'))

pickle.dump(trn_wiki, open(PATH/'trn_wiki_en.pkl', 'wb'))
pickle.dump(val_wiki, open(PATH/'val_wiki_en.pkl', 'wb'))

trn_poems,val_poems = pickle.load(open(PATH/'trn_poems_en.pkl', 'rb')), pickle.load(open(PATH/'val_poems_en.pkl', 'rb')) 
trn_wiki,val_wiki = pickle.load(open(PATH/'trn_wiki_en.pkl', 'rb')), pickle.load(open(PATH/'val_wiki_en.pkl', 'rb'))

# %%
len(trn_poems), len(val_poems), len(trn_wiki), len(val_wiki)
# Out:
# (596, 150, 3244, 812)

# %%
def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i+n]

# %%
trn_poems_chunk = list(chunks([tok for poem in trn_poems for tok in poem],50))
val_poems_chunk = list(chunks([tok for poem in val_poems for tok in poem],50))

trn_wiki_chunk = list(chunks([tok for art in trn_wiki for tok in art],200))#[:len(trn_poems)*6]
val_wiki_chunk = list(chunks([tok for art in val_wiki for tok in art],200))#[:len(val_poems)*6]

# %%
len(trn_wiki_chunk), len(trn_poems_chunk), len(val_poems_chunk), len(val_wiki_chunk), len(trn_poems), len(val_poems), len(trn_wiki), len(val_wiki)
# Out:
# (7036, 3999, 771, 1741, 596, 150, 3244, 812)

# %%
import collections

def toks2ids(tok, pre):
    freq = collections.Counter(p for o in tok for p in o)
    itos = [o for o,c in freq.most_common(30000)]
    itos.insert(0, '_bos_')
    itos.insert(1, '_pad_')
    itos.insert(2, '_eos_')
    itos.insert(3, '_unk')
    stoi = collections.defaultdict(lambda: 3, {v:k for k,v in enumerate(itos)})
    pickle.dump(itos, open(PATH/f'{pre}_itos.pkl', 'wb'))
    return itos,stoi

# %%
itos,stoi = toks2ids(trn_poems, 'en_2')
itos_d,stoi_d = toks2ids(trn_poems+trn_wiki, 'en_d')

# %%
itos = pickle.load(open(PATH/'en_2_itos.pkl', 'rb'))
stoi = collections.defaultdict(lambda: 3, {v:k for k,v in enumerate(itos)})
itos_d = pickle.load(open(PATH/'en_d_itos.pkl', 'rb'))
stoi_d = collections.defaultdict(lambda: 3, {v:k for k,v in enumerate(itos)})

# %%
len(stoi_d), len(stoi)
# Out:
# (30004, 26125)

# %%
trn_p_ids = np.array([[0] + [stoi[o] if o in stoi else 3 for o in p] + [2] for p in trn_poems_chunk])
val_p_ids = np.array([[0] + [stoi[o] if o in stoi else 3 for o in p] + [2] for p in val_poems_chunk])
trn_w_ids = np.array([[0] + [stoi[o] if o in stoi else 3 for o in p] + [2] for p in trn_wiki_chunk])
val_w_ids = np.array([[0] + [stoi[o] if o in stoi else 3 for o in p] + [2] for p in val_wiki_chunk])

# %%
sum(len(i) for i in val_p_ids)/len(val_p_ids)
# Out:
# 201.765503875969

# %%
import io

def load_vectors(fname):
    fin = io.open(fname, 'r', encoding='utf-8', newline='\n', errors='ignore')
    header = fin.readline().split()
    n, d = header[0], header[1]
    data = {}
    #partitions = [fin[:]]
    for line in fin:
        tokens = line.rstrip().split(' ')
        data[tokens[0]] = np.array(tokens[1:], dtype=float)
    return data, n, d

# %%
en_vecs, vs, dim_en_vec = load_vectors(str(PATH/'wiki-news-300d-1M.vec'))

# %%
class GANDataset(Dataset):
    def __init__(self, x): 
        self.x = x
    def __getitem__(self, idx):
        seq_len = len(self.x[idx])
        return A(self.x[idx][:seq_len//2]), A(self.x[idx][seq_len//2:])
    def __len__(self): return len(self.x)
    
class DiscDataset(Dataset):
    def __init__(self, real, fake): 
        self.real = real
        self.fake = fake
    def __getitem__(self, idx):
        return A(self.real[idx]), A(self.fake[idx])
    def __len__(self): return len(self.real)

# %%
trn_seq2seq_ds = GANDataset(trn_p_ids)
val_seq2seq_ds = GANDataset(val_p_ids)

trn_gan_ds = GANDataset(trn_p_ids)
val_gan_ds = GANDataset(val_p_ids)

trn_disc_ds = DiscDataset(trn_p_ids, trn_w_ids[:len(trn_p_ids)])
val_disc_ds = DiscDataset(val_p_ids, val_w_ids[:len(trn_p_ids)])

# %%
bs=64

trn_samp = SortishSampler(trn_p_ids, lambda x: len(trn_p_ids[x]), bs)
val_samp = SortSampler(val_p_ids, lambda x: len(val_p_ids[x]))

trn_seq2seq_dl = DataLoader(trn_seq2seq_ds,batch_size=bs,pad_idx=1,num_workers=1,pre_pad=False, transpose_y=True, transpose=True, sampler=trn_samp)
val_seq2seq_dl = DataLoader(val_seq2seq_ds,batch_size=bs,pad_idx=1,num_workers=1,pre_pad=False, transpose_y=True, transpose=True, sampler=val_samp)

trn_gan_dl = DataLoader(trn_gan_ds,batch_size=bs,pad_idx=1,num_workers=1,pre_pad=False, transpose_y=True, transpose=True, sampler=trn_samp)
val_gan_dl = DataLoader(val_gan_ds,batch_size=bs,pad_idx=1,num_workers=1,pre_pad=False, transpose_y=True, transpose=True, sampler=val_samp)

trn_disc_dl = DataLoader(trn_disc_ds,batch_size=bs//2,pad_idx=1,num_workers=1,pre_pad=False, transpose_y=True, transpose=True)
val_disc_dl = DataLoader(val_disc_ds,batch_size=bs//2,pad_idx=1,num_workers=1,pre_pad=False, transpose_y=True, transpose=True)

# %%
x, y = next(iter(trn_disc_dl))
x.size(), y.size()
# Out:
# (torch.Size([52, 32]), torch.Size([202, 32]))

# %%
def rand_t(*sz): return torch.randn(sz)/math.sqrt(sz[0])
def rand_p(*sz): return nn.Parameter(rand_t(*sz))

# %%
class Seq2SeqAttention(nn.Module):
    def __init__(self, vecs, itos, em_sz, nh, nl=2, dropf=1.0):
        super().__init__()
        self.emb_enc = create_emb(vecs, itos, em_sz)
        self.nl,self.nh = nl,nh
        self.lstm_enc = nn.LSTM(em_sz, nh, num_layers=nl, dropout=0.25*dropf, bidirectional=True)
        self.out_enc = nn.Linear(nh*2, em_sz, bias=False)
        self.drop_enc = nn.Dropout(0.25*dropf)
        self.emb_dec = create_emb(vecs, itos, em_sz)
        self.lstm_dec = nn.LSTM(em_sz, em_sz, num_layers=nl, dropout=0.1)
        self.emb_enc_drop = nn.Dropout(0.15*dropf)
        self.out_drop = nn.Dropout(0.35*dropf)
        self.out = nn.Linear(em_sz, len(itos))
        self.out.weight.data = self.emb_dec.weight.data

        self.W1 = rand_p(nh*2, em_sz)
        self.l2 = nn.Linear(em_sz, em_sz)
        self.l3 = nn.Linear(em_sz+nh*2, em_sz)
        self.V = rand_p(em_sz)

    def forward(self, inp, y=None,sampling=False):
        sl,bs = inp.size()
        h_n, c_n = self.initHidden(bs)
        emb = self.emb_enc_drop(self.emb_enc(inp))
        enc_out, (h_n, c_n) = self.lstm_enc(emb, (h_n, c_n))
        h_n = h_n.view(2,2,bs,-1).permute(0,2,1,3).contiguous().view(self.nl,bs,-1)
        h_n = self.out_enc(self.drop_enc(h_n))
        c_n = c_n.view(2,2,bs,-1).permute(0,2,1,3).contiguous().view(self.nl,bs,-1)
        c_n = self.out_enc(self.drop_enc(c_n))
        pg_loss=0
        dec_inp = V(torch.zeros(bs).long())
        res,attns = [],[]
        samples = V(torch.zeros(sl, bs).long())
        w1e = enc_out @ self.W1
        for i in range(sl):
            w2h = self.l2(h_n[-1])
            u = torch.tanh(w1e + w2h)
            a = F.softmax(u @ self.V, 0)
            attns.append(a)
            Xa = (a.unsqueeze(2) * enc_out).sum(0)
            emb = self.emb_dec(dec_inp)
            wgt_enc = self.l3(torch.cat([emb, Xa], 1))
            outp, (h_n, c_n) = self.lstm_dec(wgt_enc.unsqueeze(0), (h_n,c_n))
            outp = self.out(self.out_drop(outp[0]))
            res.append(outp)
            if not sampling:
                dec_inp = V(outp.data.max(1)[1])
            else:
                outp = F.log_softmax(outp, dim=1)
                outp = torch.multinomial(torch.exp(outp), 1)
                samples[i, :] = outp.view(-1).data
                dec_inp = V(outp.view(-1))
            if (dec_inp==1).all(): break
            if (y is not None):
                if i>=len(y): break
                dec_inp = y[i]
        h_n = repackage_hidden(h_n)
        c_n = repackage_hidden(c_n)
        
        return torch.stack(res), samples
    
    
    def initHidden(self, bs): return V(torch.zeros(self.nl*2, bs, self.nh)), V(torch.zeros(self.nl*2, bs, self.nh))

# %%
def repackage_hidden(h):
    return h.detach() if isinstance(h, torch.Tensor) else tuple(repackage_hidden(v) for v in h)

# %%
def seq2seq_loss(input, target, kld_weight=0):
    decoded = input
    sl, bs = target.size()
    sl_in,bs_in,nc = decoded.size()
    if sl>sl_in: decoded = F.pad(decoded, (0,0,0,0,0,sl-sl_in))
    decoded = decoded[:sl]
    return F.cross_entropy(decoded.view(-1,nc), target.view(-1))

# %%
class TextDicriminator(nn.Module):
    def __init__(self,vecs,itos,em_sz,nh,nl=2, dropf=1):
        super().__init__()
        #encoder
        self.emb_enc = create_emb(vecs,itos,em_sz)
        self.emb_enc_drop = nn.Dropout(0.15*dropf)
        self.nl,self.nh, self.vs = nl,nh,len(itos)
        self.lstm_enc = nn.LSTM(em_sz, nh, num_layers=nl, dropout=0.25*dropf, bidirectional=True)
        self.out_drop = nn.Dropout(0.35*dropf)
        #attention
        self.W1 = rand_p(nh*2, em_sz)
        self.l2 = nn.Linear(nh*2, em_sz)
        self.V = rand_p(em_sz)
        
        #classifier
        #self.out_enc = nn.Linear(nh*3*2, em_sz)
        #self.nonlin = nn.Tanh()
        self.out = nn.Linear(nh*2, 1)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, inp, y=None):
        #encode
        sl,bs = inp.size()
        hidden = self.initHidden(bs) # nl*bs*nh
        emb = self.emb_enc_drop(self.emb_enc(inp)) #sl*bs*em_sz
        enc_out, (h_n, c_n) = self.lstm_enc(emb,hidden) #enc_out: sl*bs*nh, hidden: nl*bs*nh
        #classify
        h_n = h_n.view(2,2,bs,-1).permute(0,2,1,3).contiguous().view(self.nl,bs,-1)
        #hidden = torch.cat([enc_out.max(0)[0],enc_out.sum(0),h_n[-1]],1)
        #c = self.nonlin(self.out_enc(hidden))
        #c = self.sigmoid(self.out(self.out_drop(c)))
        out = []
        w1e = enc_out @ self.W1
        #for i in range(sl):
        w2h = self.l2(h_n[-1])
        u = torch.tanh(w1e + w2h)
        a = F.softmax(u @ self.V, 0)
        #out.append(a)
        Xa = (a.unsqueeze(2) * enc_out).sum(0)
            #emb = self.emb_enc(inp[i])
        #wgt_enc = self.l3(torch.cat([h_n[-1], Xa], 1))
            #c = self.nonlin(self.out_enc(hidden))
        c = self.sigmoid(self.out(self.out_drop(Xa)))
            #out.append(self.sigmoid(wgt_enc))
            #enc = self.nonlin(self.out_enc(torch.cat([enc_out.max(0)[0],enc_out.sum(0),enc_out[i]],1)))
            #out.append(self.sigmoid(self.out(self.out_drop(enc))))
        #h_n = repackage_hidden(h_n)
        #c_n = repackage_hidden(c_n)
        #return out
        return  c, a

    def initHidden(self, bs): return V(torch.zeros(self.nl*2, bs, self.nh)), V(torch.zeros(self.nl*2, bs, self.nh))

# %%
def create_emb(vecs, itos, em_sz):
    emb = nn.Embedding(len(itos), em_sz, padding_idx=1)
    wgts = emb.weight.data
    miss = []
    for i,w in enumerate(itos):
        try: wgts[i] = torch.from_numpy(vecs[w])
        except: miss.append(w)
    print(len(miss),miss[5:10])
    return emb

# %%
disc = TextDicriminator(en_vecs, itos_d, dim_en_vec, 128)
gen = Seq2SeqAttention(en_vecs, itos, dim_en_vec, 128)
gen.cuda(); disc.cuda();
# Out:
# 4442 ['<unk>', 't_up', '@.@', '@,@', ',--']
# 12516 [',--', '’s', 'tk_rep', ';--', 'keewis']
# 12516 [',--', '’s', 'tk_rep', ';--', 'keewis']

# %%
from torch import optim

optimizerD = optim.Adam(disc.parameters(), lr = 1e-3)
optimizerG = optim.Adam(gen.parameters(), lr = 1e-3, betas=(0.7, 0.8))

# %%
def train_gen(gen, epochs, trn_dl, val_dl, crit, opt):
    n = epochs
    for epoch in range(epochs):
        with tqdm(total=len(trn_dl)) as pbar:
            gen.train()
            for i, ds in enumerate(trn_dl):
                x, y = ds
                sl, bs = x.size()
                fake = gen(x,y)
                gen.zero_grad()
                gen_loss = creative_loss = crit(fake[0],y)
                gen_loss.backward()
                opt.step()
                torch.nn.utils.clip_grad_norm_(gen.parameters(), 8.)
                pbar.update()
        print(f'Epoch {epoch}:')
        print(f'Loss_G {creative_loss.data.item()} Ppx {torch.exp(creative_loss)}')
        gen.eval()
        for i, ds in enumerate(val_dl):
            x, y = ds
            sl, bs = x.size()
            fake = gen(x)
            gen_loss = creative_loss = crit(fake[0],y)
        print(f'Val Loss_G {creative_loss.data.item()} Ppx {torch.exp(creative_loss)}')

# %%
train_gen(gen,20, trn_seq2seq_dl, val_seq2seq_dl,seq2seq_loss, optimizerG)
# Out:
# 100%|██████████| 6246/6246 [17:44<00:00,  5.67it/s]
# Epoch 0:
# Loss_G 4.81662130355835 Ppx 123.54695892333984
# Val Loss_G 7.573636054992676 Ppx 1946.203857421875
# 100%|██████████| 6246/6246 [18:28<00:00,  5.66it/s]
# Epoch 1:
# Loss_G 5.159106254577637 Ppx 174.00885009765625
# Val Loss_G 7.47801399230957 Ppx 1768.724609375
# 100%|██████████| 6246/6246 [17:42<00:00,  5.97it/s]
# Epoch 2:
# Loss_G 4.431586742401123 Ppx 84.06470489501953
# Val Loss_G 8.16218090057373 Ppx 3505.823974609375
# 100%|██████████| 6246/6246 [17:00<00:00,  6.18it/s]
# Epoch 3:
# Loss_G 4.358253002166748 Ppx 78.12053680419922
# Val Loss_G 8.25850772857666 Ppx 3860.3291015625
#  31%|███       | 1922/6246 [05:20<11:56,  6.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-162-3fea5372597b> in <module>()
# ----> 1 train_gen(gen,20, trn_seq2seq_dl, val_seq2seq_dl,seq2seq_loss, optimizerG)
#
# <ipython-input-161-db353d792084> in train_gen(gen, epochs, trn_dl, val_dl, crit, opt)
#      10                 gen.zero_grad()
#      11                 gen_loss = creative_loss = crit(fake[0],y)
# ---> 12                 gen_loss.backward()
#      13                 opt.step()
#      14                 torch.nn.utils.clip_grad_norm_(gen.parameters(), 8.)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
torch.save(gen.state_dict(), PATH/'models/seq2seq_en_poems2.h5')

# %%
gen.load_state_dict(torch.load(PATH/'models/seq2seq_en_poems2.h5', map_location=lambda storage, loc: storage))

# %%
def produce_out(val_dl, model, use_cuda=True):
    model.eval()
    out = []
    loss = 0
    for i, ds in enumerate(val_dl):
        x, y = ds
        bptt, bs = x.size()
        y = y.view(bptt, bs)
        if use_cuda:
            x = x.cuda()
        probs = model(x)
        loss = seq2seq_loss(probs[0], y)
        preds = np.array(probs[0].topk(2)[1])
        for i in range(x.size(1)):
            seed = ' '.join([itos[o] for o in x[:,i] if o not in [0,1,2,3]])
            actual = ' '.join([itos[o] for o in y[:,i] if o not in [0,1,2,3]])
            fake = ' '.join([itos[o[0]] if o[0] not in [0,1,2,3] else itos[o[-1]] for o in preds[:,i]])
            out.append([seed,actual,fake])
    print(torch.exp(loss))
    return out

# %%
out_seq2seq = produce_out(val_gan_dl, gen)
pickle.dump(out_seq2seq, (PATH/'seq2seq_en.pkl').open('wb'))
# Out:
# tensor(64036.4219, device='cuda:0', grad_fn=<ExpBackward>)

# %%
out_seq2seq = pickle.load((PATH/'seq2seq_en.pkl').open('rb'))
out_seq2seq[1][0],out_seq2seq[1][1], out_seq2seq[1][2]
# Out:
# ('a on both sides you fall into love , and as you fall out the time while under its are like',
#  'on the single does not cut how soon hath time , the subtle thief of youth , on his wing my three',
#  'dianna , but the same was not to . the first of the end was the first of the most river , the <unk> @-@ <unk>')

# %%
out_seq2seq
# Out:
# [['i am hunting my wayward heart.i can feel that steady drum beat , following the ruby fingertips like , it to the',
#   'continually the heart flees , running from this only ardor can all know it is only must armor ourselves is',
#   'world , with the and , as the my soul , with joy and . . at the from of a , never could be ,'],
#  ['a on both sides -as you fall into love , and as you fall out -all the time while under its are like',
#   'on the single does not cut how soon hath time , the subtle thief of youth , on his wing my three',
#   'the the to you and day you will never meet the way of the and of his the , and the bellman in tell you ,'],
#  ['and year ! my days fly on full career , but my late spring no bud or blossom . perhaps my',
#   'might deceive the truth , that i to manhood am arrived so near , and inward doth much less appear , that some',
#   'love , and that is there ? no , but here is there to - day and be the same , that s not even no'],
#  ['more - happy spirits . yet be it less or more , or soon or slow , it shall be still in',
#   'measure even to that same lot , however mean or high , toward which time leads me , and the will of heaven ; all',
#   'the , great and light , and the other most , only other would come , we know all where he saw the and of him'],
#  ['is , if i have grace to use it so , as ever in my great eye . a t_up boat beneath a sunny',
#   'sky , lingering onward dreamilyin an evening of july --children three that nestle near , eager eye and willing ear , pleased a simple tale',
#   ', i heard a voice -- yet i could but be done , i m with you in rockland where you are free , but the'],
#  ['to hear --long has paled that sunny sky : echoes fade and memories die : autumn frosts have slain july.still she haunts me , phantomwise',
#   ', alice moving under skiesnever seen by waking eyes.children yet , the tale to hear , eager eye and willing ear , lovingly shall nestle',
#   ', and a , to be a , so long , but , if they meet to their heart , for even the to the ,'],
#  ['near.in a wonderland they lie , dreaming as the days go by , dreaming as the summers die : ever drifting down the stream --lingering',
#   'in the golden dream --life , what is it but a dream ? my sleeping children are still flying dreams in their goose - down',
#   'the world the rain - in the morning , sky and the wind to the rain , we know not what the world will be like'],
#  ['heads . the of the river singing morning songs fish watch their turn sun - white . the grey - green',
#   ', like hair points the waters drift . all is morning hush and bird beautiful . five months ago the stream did',
#   'the the the the the the the the that is of the the the , whose eyes are the the dead that s a the ,'],
#  ['flow , the lilies bloomed within the sedge , and we were lingering to and fro , where none will track thee in this snow',
#   ', along the stream , beside the , sweet , be free to love and if i do not hear thy foot ,',
#   ', and when the waves are made , as the clouds of our love , we are not long , and be the thing in which'],
#  ['the frozen river is as mute , the flowers have dried down to the root : and why , since these be changed since may',
#   ', shouldst thou change less than slow , slow as the winter tears have drifted to mine my poor cheeks , five',
#   'be , but never found it is in the life of their eyes , and had a thing with a little , but over and ,'],
#  ['months blushing at thy praises so , put on for a , sweet , be free to praise and if my',
#   'face is turned too pale , it was thine oath that first did fail , was thy love proved false and frail ,',
#   'love to be a thing with that alone are not a and that is . when at last i saw it was now - the ,'],
#  ['why , since these be changed , should i change less than thou . too my father got up put his clothes',
#   'on in the cold , then with cracked hands that labor in the weather fires blaze . no one ever',
#   ', and , as if it had not been , we ve no good and to - day , to be happy : i ve heard'],
#  ['wake and hear the cold , the rooms were warm , he d call , and slowly i would rise and dress',
#   ', fearing the chronic of that house , speaking indifferently to him , who had driven out the polished my good shoes as',
#   ', and all that come . i ve been too , a little tree , and all the same way . i feel a voice you'],
#  ['did i know , what did i loves and lonely offices ? swiftly walk oer the western wave , spirit of',
#   'of the misty eastern cave , where , all the long and lone daylight , thou dreams of joy and fear , which make',
#  ['floodreflected back the dancing form again.could ye mistake the look , with beauty fraught , that nature gave to help ye on your way?the image',
#   'floating on the billows taughtthe art the fleeting shadow to portray.from her own being torn apart , her phantom , beauteous as a dream ,',
#   ', the best , with a mind to - day , to the child to say to her , i , her , her , face'],
#  ['she plunged into the silvery stream , surrendering to her spoilers art.creative power soon in your breast unfolded;too noble far , not idly to conceive',
#   ', the shadows form in sand , in clay ye moulded , and made it in the sketch its being leave.the longing thirst for action',
#   ', the to the , there , in all the , then , the my to the , , were now that we to find ,'],
#  ['then awoke ,-- and from your breast the first creation broke.by contemplation captive made , ensnared by your discerning eye , the friendly phantoms soon',
#   'betrayedthe talisman that roused your ecstasy.the laws of wonder - working might , the stores by beauty brought to light , inventive reason in soft',
#   ', the , from his , black as a dead heart is , by a love the soul is still , and still the voice is'],
#  ['union plannedto blend together neath your forming hand.the obelisk , the pyramid ascended , the hermes stood , the column sprang on high , the',
#   'reed poured forth the woodland melody , immortal song on victors deeds attended.the fairest flowers that decked the earth , into a nosegay , with',
#   'light of the that , like life & gold , the as first a thing of , and all the , light on his all ,'],
#  ['wise choice combined , thus the first art from nature had its birth;into a garland then were nosegays twined , and from the works that',
#   'mortal hands had made , a second , nobler art was now displayed.the child of beauty , self - sufficient now , that issued from',
#   'is in his own , and all that s to be a thing that , with my mind , with that mind , that fire ,'],
#  ['your hands to perfect day , loses the chaplet that adorned its brow , soon as reality asserts its sway.the column , yielding to proportions',
#   'chains , must with its sisters join in friendly link , the hero in the hero - band must sink , the muses harp peals',
#   ', the shadow , and all the shadows in the many - black the stars will the be , if in some morning the , sea'],
#  ['forth its tuneful strains.the wondering savages soon cameto view the new creations planbehold!--the joyous crowds exclaim ,-- behold , all this is done by man!with',
#   'jocund and more social aimthe minstrels lyre their awe awoke , telling of titans , and of giants fraysand lion - slayers , turning ,',
#   'of their in , and the ocean of god , and the the , and the , as in being he , and on high ,'],
#  ['as he spoke , even into heroes those who heard his lays.for the first time the soul feels joy , by raptures blessed that calmer',
#   'are , that only greet it from afar , that passions wild can neer destroy , and that , when tasted , do not cloy.and',
#   ', to him to whom we love , to keep the world from , i , as he looked , the first - time , ,'],
#  ['now the spirit , free and fair , awoke from out its sensual sleep;by you unchained , the slave of careinto the arms of joy',
#   'could leap.each brutish barrier soon was set at naught , humanity first graced the cloudless brow , and the majestic , noble stranger , thought',
#   ', the to be a sea , a , to his in life , the the , the the , the the morning , there ,'],
#  [', from out the wondering brain sprang boldly now.man in his glory stood upright , and showed the stars his kingly face;his speaking glance the',
#   'suns bright lightblessed in the realms sublime of space.upon the cheek now bloomed the smile , the voices soulful harmonyexpanded into song the while ,',
#   'the , with their a , were the first of the first , were all his way to his , then , with joy did not'],
#  ['and feeling swam in the moist eye;and from the mouth , with spirit teeming oer , jest , sweetly linked with grace , began to',
#   'pour.sunk in the instincts of the worm , by naught but sensual lust possessed , ye recognized within his breastlove - spirituals noble germ;and that',
#   'the , from the sea - , out of the , & his , as oer the first time & , & yet great tears ,'],
#  ['this germ of love so blestescaped the senses abject load , to the first pastoral song he owed.raised to the dignity of thought , passions',
#   'more calm to flow were taughtfrom the bards mouth with melody.the cheeks with dewy softness burned;the longing that , though quenched , still yearned ,',
#   'in such a , thou art to , with thy love at all , the great , as if the first were all , then into'],
#  ['proclaimed the spirit-harmony.the wisests wisdom , and the strongests vigor ,-- the meekests meekness , and the noblests grace , by you were knit together',
#   'in one figure , wreathing a radiant glory round the place.man at the unknowns sight must tremble , yet its refulgence needs must love;that mighty',
#   ', and with a mighty arms he , thou , & the last black be , its last , then their and , if his from'],
#  ['being to resemble , each glorious hero madly strove;the prototype of beautys earliest strainye made resound through natures wide domain.the passions wild and headlong course',
#   ', the ever - varying plan of fate , duty and instincts twofold force , with proving mind and guidance straightye then conducted to their',
#   ', and , and all the you are the great from the feet , & , and , with your friend , the the , are'],
#  ['ends.what nature , as she moves along , far from each other ever rends , become upon the stage , in song , members of',
#   'order , firmly bound.awed by the furies chorus dread , murder draws down upon its headthe doom of death from their wild sound.long eer the',
#   'the , with his name , its love the in - spring , where the waves with hearts of as thou art , with the world'],
#  ['wise to give a verdict dared , an iliad had fates mysteries declaredto early ages from afar;while providence in silence faredinto the world from thespis',
#   'car.yet into that worlds current so sublimeyour symmetry was borne before its time , when the dark hand of destinyfailed in your sight to part',
#   'the the one to be a thing to - the , , when the rain had been , the first man on the world , when'],
#  ['by force.what it had fashioned neath your eye , in darkness life made haste to die , ere it fulfilled its beauteous course.then ye with',
#   'bold and self - sufficient mightled the arch further through the futures night : then , too , ye plunged , without a fear ,',
#   'the a , - by - a - it came , we , too , into our own when i could , your little heart life'],
#  ['into avernus ocean black , and found the vanished life so dearbeyond the urn , and brought it back.a blooming pollux - form appeared now',
#   'soon , on castor leaning , and enshrined in light -- the shadow that is seen upon the moon , ere she has filled her',
#   ', and that , in its life , the bellman in their feet , each , too , no , no longer can to see ,'],
#  ['silvery circle bright!yet higher ,-- higher still above the earthinventive genius never ceased to rise : creations from creations had their birth , and harmonies',
#   'from harmonies.what here alone enchants the ravished sight , a nobler beauty yonder must obey;the graceful charms that in the nymph unite , in the',
#   'the , from the black - the - , when the water at first , the the , and all the stars all , and the'],
#  ['divine athene melt away;the strength with which the wrestler is endowed , in the gods beauty we no longer find : the wonder of his',
#   'time -- joves image proud -- in the olympian temple is enshrined.the world , transformed by industrys bold hand , the human heart , by',
#   'soul , of all the world of god , the soul , or see the first of your heart , all things of their the ,'],
#  ['new - born instincts moved , that have in burning fights been fully proved , your circle of creation now expand.advancing man bears on his',
#   'soaring pinions , in gratitude , art with him in his flight , and out of natures now - enriched dominionsnew worlds of beauty issue',
#   'soul , by his soul , his arms , and silent , his and , and a thing of to - a - born place on'],
#  ['forth to light.the barriers upon knowledge are oerthrown;the spirit that , with pleasure soon matured , has in your easy triumphs been inuredto hasten through',
#   'an artist - whole of graces , natures more distant columns duly places.and overtakes her on her pathway lone.he weighs her now with weights that',
#   'the to of a living , set in the water - a - to - the , his hearts should feel the child , and still'],
#  ['- born spring;twice was the youth of time renewed , twice , from the seeds that ye had strewed.when chased by fierce barbarian hordes away',
#   ', the last remaining votive brand ye torefrom orients altars , now pollutions prey , and to these western lands in safety bore.the fugitive from',
#   ', and the , as if they were , and even the it came out of his , and from my breast the soul ’s ,'],
#  ['yonder eastern shore , the youthful day , the west her dwelling made;and on hesperias plains sprang up once moreionias flowers , in pristine bloom',
#   'arrayed.over the spirit fairer nature shed , with soft refulgence , a reflection bright , and through the graceful soul with stately treadadvanced the mighty',
#   ', and , with the , days , light , with summer lost , and on thee now the day , with , with tears ,'],
#  ['deity of light.millions of chains were burst asunder then , and to the slave then human laws applied , and mildly rose the younger race',
#   'of men , as brethren , gently wandering side by side , with noble inward ecstasy , the bliss imparted ye receive , and in',
#   ', and , with a , - as in vain ! through he did not give , then back in the , when the in ,'],
#  ['the veil of modesty , with silent merit take your leave.if on the paths of thought , so freely given , the searcher now with',
#   'daring fortune stands , and , by triumphant paeans onward driven , would seize upon the crown with dauntless hands -- if he with grovelling',
#   'the , which , as my soul , the soul of death , in the mighty arms of he , while he has made a man'],
#  ['hirelings paythinks to dismiss his glorious guide -- or , with the first slaves - place arrayart near the throne his dream supplied -- forgive',
#   'him!--oer your head to - dayhovers perfections crown in pride , with you the earliest plant spring had , soul - forming nature first began;with',
#   'to the heart , who the soul to - day , to - , the with it were light , where was the it , before'],
#  ['you , the harvest - chaplet glad , perfected nature ends her plan.the art creative , that all - modestly arosefrom clay and stone ,',
#   'with silent triumph throwsits arms around the spirits vast domain.what in the land of knowledge the discoverer knows , he knows , discovers , only',
#   'and in the mighty arms she of the mountain , the blue , the the , the the , the , , - the , ,'],
#  ['for your gainthe treasures that the thinker has amassed , he will enjoy within your arms alone , soon as his knowledge , beauty -',
#   'ripe at last.to art ennobled shall have grown ,-- soon as with you he scales a mountain - height , and there , illumined by',
#   ', and , with truth , and , from all the world & the by , where the water ’s all , the world from ,'],
#  ['the setting sun , the smiling valley bursts upon his sight.the richer ye reward the eager gazethe higher , fairer orders that the mindmay traverse',
#   'with its magic rays , or compass with enjoyment unconfined -- the wider thoughts and feelings open lieto more luxuriant floods of harmony.to beautys richer',
#   'of a , whose tears are a in this , who on thee i , a voice -- to be a thing with of , ,'],
#  [', more majestic stream ,-- the fair members of the worlds vast scheme , that , maimed , disgrace on his creation bring , he',
#   'sees the lofty forms then perfecting -- the fairer riddles come from out the night -- the richer is the world his arms enclose ,',
#   ', with his life - blood it did not see the , from his face the most - its the , his soul was , by'],
#  ['the broader stream the sea with which he flows -- the weaker , too , is destinys blind might -- the nobler instincts does he',
#   'prove -- the smaller he himself , the greater grows his love.thus is he led , in still and hidden race , by poetry ,',
#   ', the , from his , the first , the gods in living is the eye , and to his heart the soul is , ,'],
#  ['who strews his path with flowers , through ever - purer forms , and purer powers , through ever higher heights , and fairer grace.at',
#   'length , arrived at the ripe goal of time ,-- yet one more inspiration all - sublime , poetic outburst of mans latest youth ,',
#   ', the one , by night he loved his way , he went , as though , their last blue , the first , his before'],
#  ['and -- he will glide into the arms of truth!herself , the gentle cypria , illumined by her fiery crown , then stands before her',
#   'full - grown sonunveiled -- as great urania;the sooner only by him caught , the fairer he had fled away!thus stood , in wonder rapture',
#   ', as she was made of him , as his , as through his first , the first , the first one eye can the ,'],
#  ['- fraught , ulysses noble son that day , when the sage mentor who his youth beguiled;herself transfigured as joves glorious child!mans honor is confided',
#   'to your hand ,-- there let it well protected be!it sinks with you ! with you it will expand!poesys sacred sorceryobeys a world - plan',
#   'to the , if they hear it no longer a thing in which the days have heard the in of your the the world was ,'],
#  ['wise and good;in silence let it swell the floodof mighty - rolling harmony.by her own time viewed with disdain , let solemn truth in song',
#   'remain , and let the muses band defend her!in all the fullness of her splendor , let her survive in numbers glorious , more dread',
#   'of the earth , and from her it be the world , with silent hand , the first - shadow of beauty , when all ,'],
#  [', when veiled her charms appear , and vengeance take , with strains victorious , on her tormentors ear!the freest mothers children free , with',
#   'steadfast countenance then riseto highest beautys radiancy , and every other crown despise!the sisters who escaped you here , within your mothers arms yell meet;what',
#   'the sea and a , to feel the the a dead he , who , where , or the other , as if the first time'],
#  ['noble spirits may revere , must be deserving and complete.high over your own course of timeexalt yourselves with pinion bold , and dimly let your',
#   'glass sublimethe coming century unfold!on thousand roads advancing fastof ever - rich variety , with fond embraces meet at lastbefore the throne of harmony!as into',
#   'soul the in thy love - and , when the soul ’s great to , and all the you are as a the the , from'],
#  ['seven mild rays we viewwith softness break the glimmer white , as rainbow - beams of sevenfold huedissolve again in that soft light , in',
#   'clearness thousandfold thus throwyour magic round the ravished gaze ,-- into one stream of light thus flow ,-- one bond of truth that neer decays',
#   'the sea - wind , the spirit , and sea - moon , far far from those bright , the dark - world which , ,'],
#  ['! good - night ? ah ! no ; the hour is those it should us remain together still , then it',
#   'will be good can i call the lone night good , though thy sweet wishes wing its it not said , thought ,',
#   'is not a word . this is the same that one . where the voice of the the to be — and the that must be'],
#  ['understood it will be -- good hearts which near each other evening close to morning light , the night is good ;',
#   'because , my love , they never say good - night some of us would have conceived out of our own no',
#   'and he will come back in the , , and all the soul of the the , of the the , were the best , from'],
#  [', without songs and poetry -- or have invented poetry and a comb of cells for the by ignorance , a succession',
#   'of new worlds , or once thought most people were italian , or be white and like',
#   ', the to be a - a , have lost the , if his call at them , the the of his . he d have'],
#  [', a rare i believed only could be one year in the majors , ford was',
#   'by the play ball in the the signal , long branch , new night game , the silver the',
#   'the love is the the in which the way you can not say , is it that is . or is not one of the from'],
#  ['lights , his pink like a a liked or hated : a , a mere white the - off',
#   'the grass , white and uniform , and white the of his he shifted his cap : so ordinary and',
#   'the and , like a the and is — and in that i love you , are you , my soul is at , when the'],
#  ['distinct , so close up , that i if i could have made him up , imagined him as i ball , a',
#   'in the black the sky . tight red . the white : the nothing . color of the pastand of',
#   'world is in the to the morning , i saw a house , a the , his and the first , were the bird my before'],
#  ['the future , of the movie rest and of blank could have . the mind . the , the picked out',
#   'by the . a few years a blanket in the the same girl and i came togetherto the faint',
#   'of the to be — and the to be said , the only good but take - back by , and those who will be ,'],
#  ['and , the time , i devised a left - more ford : a were amazed by',
#   ', when he was young , he refused to pitch on . no , time , thou shalt not boast that i',
#   'the and , when the world was , only for the first , and were now . you should have been so , we might ,'],
#  ['do pyramids built up with newer me are nothing novel , nothing are but of a former dates are brief',
#   ', and therefore we thou dost upon us that is old , and rather make them born to our think that we',
#   ', and that great and in his , all things are . i ve heard it will be in thought , all things , but for'],
#  ['before have heard them and thee i both , not wondring at the present , nor the past , for thy records',
#   ', and what we see doth lie , made more or less by thy continual haste : this i do vow and this shall ever',
#   ', and all that are , as if your soul the soul is . when i look and hear the days , all we are only'],
#  ['be : i will be true despite thy scythe and thee . a slight rain comes , bathed in dawn light.i hear it among',
#   'leaves before . soon it the soil and , , follows clouds away . grace thatch homes for a and',
#   'the world from thee thou , long and , with death should , days of days , bright clouds , go on the this , street'],
#  ['herds of things wild . then the scent of musk opens a mountain -- and lingers on past noon . i must confess',
#   'that this is my first the leaves change in laid on my a rather large tree today , and what a marvel',
#   'to the mind , and found it the same , that place in a moment , not a thing that to be up , it was'],
#  ['it laid next to me , yet was the fact that he might get dirt in his me , it was',
#   'a much greater stared in the oranges blue funny how a moment like make me realize how are',
#   'a , said that must not be , and you were nt and . . at first , the the of the and of his ,'],
#  ['for each i was busy feeling of the cool ground that was my staring up at the leaves until they',
#   'and blurred together , he only seemed to and , as if he was annoyed or committing such a childish ,',
#   'the , great and , now , and found me the green , and take my life with day . to look at the rest ,'],
#  ['i learned the he tells me that i m because i am an artist , i see beauty in everything.i am a',
#   'reads more than just find joy in taking the time to smell the roses be by the little he has only',
#   'the world is , but the soul ’s great you , and the bellman would the or , when the sun comes on , i shall'],
#  ['found a path by rolls the phantom chimney - smoke beneath the wintry moon ; for miles on miles , by sound',
#   ', the world lies wrapt in its cloak , and the nights icy earthward in great brimming wells of luminous , frosty',
#   'the the , and the , were not an in which the world did not go into the to air , with joy , was on'],
#  ['. far up the , drifted deep , where frost - fences gleam ; beneath the skys wan , shimmering sleep my solitary',
#   'way i keep across the worlds white only living moving thing in all this mighty in the eastern range of hill , the',
#   ', and the sky is not a the the to that time when i heard this you are still with me , and i will never'],
#  ['thin wood stirs in its sleep and then is still ( like age ) at the winds shadow follows my footsteps',
#   'where i go , a giant on the where the rivers arms are wound , and icy cling , there comes to',
#   ', and all is still . for sea - bird are not a - a , and the other will the in of this the ,'],
#  ['me as in a a far - off clear , thin , vibrant the distant of frost - elves as they come',
#   'and go , , in silver chains , his stand upon the hills bleak crest and note the far night world : the',
#   ', and that is it ? no longer a the , whose eyes are it so much for me , the shadow of my love ,'],
#  ['mighty lake whose passionate breast , into rest , in sleep is : the heavens whose wondrous host wheel white',
#   'from flaming coast to down the nights dim luminous ways , they come once more , those great star - watchers of old',
#   ', and all are made to - day , to - night to be . now it too , for all the time to be ,'],
#  ['days the lonely , calm - ones , whose still gaze , on old - time , orient shore , dreamed in the wheeling sons',
#   'to be a thing in , the very same , and now was was , , when the first had been , it seemed too ,'],
#  ['smile on his lips and a hope in his all is over and all is done , now which of these men was the',
#   'richer one ? tread lightly , she is the snow , speak gently , she can hearthe daisies her bright golden with',
#   'world , the first , like time to the and . when the sky was done , said the , and all that stars are no'],
#  ['rust , she that was young and to , white as snow , she hardly was a woman , she',
#   ', heavy stone , lie on her breast , i my heart alone , she is at , peace , she can not',
#   'not the world can not be to be , and you are not a - , when the beaver all , and then the , ,'],
# ...
#  ['wrath ; and here one offered to a thirsty words half - drowned amid those thunders frozen ( there were many',
#   'tooth - ache in each . there comes a happy pause , for human not endure to dance without every one must',
#   'the , by the the , are the in his . all this is still with that night , but at that time for the ,'],
#  ['reach the point at absolute . at such a moment ladies learn to give , to who would urge them over -',
#   'much , a flat and yet decided love such . there comes a welcome - hope revives , and fading eyes grow',
#   ', to the , then with one and , and all the same that did . where the voice are to be and are all before'],
#  ['bright , and pulses quicken : incessant pop the , and busy the tongue and chicken . flushed with new life , the',
#   'crowd flows back again : and all is tangled talk and mazy motion like a waving field of golden grain , or a tempestuous',
#   'world - the , are , o - a , - , where the bellman down , and only the way ’s first , now before'],
#  ['ocean . and thus they give the time , that nature peaceful sleep and snores , to ceaseless and mindless waste',
#   'of shoes and floors . and one ( we name him not ) that flies the flowers , that the dances , and that',
#   ', and the , from the the , which we look and was , with this life - in , and are not a the from'],
#  ['shuns the , they doom to pass in solitude the hours , writing - ballads . how late it grows ! the hour',
#   'is surely should have us with its double twilight wanes , and morning comes at last , uncle , what s',
#   'of the gods is for a heart that s to see it on the dark the morning - then come at home , and you ,'],
#  ['oclock ? the uncle gravely nods , and wisely t_up may mean much , but how is one to opens his mouth -',
#   'yet out of it , methinks , no words of wisdom flow . ii empress of art , for thee i wreath with all',
#   ', and now - it was all - the - , are the thing of he with , and his the , when the bellman ,'],
#  ['too slender my muse each halting line , and for the deed accept the will ! o day of tears ! whence comes this',
#   'spectre grim , parting , like deaths cold river , souls that not he bound to thee , as thou to him , by',
#   ', and not even to keep my friend , when the last way of a the . where the you are , and you are not'],
#  ['vows , here , yet heard above ? and still it lives , that keen and heavenward flame , lives in his eye ,',
#   'and trembles in his tone : and these wild words of fury but heart that beats for thee , for thee alone ! but',
#   'and he was not the , and then the world was , no , the other would the , then his , he loved his life'],
#  ['all is lost : that mighty mind , like sweet bells , piteous sight to that the stars are fire , so',
#   'runs his moan , doubt truth herself , but not my love for thee ! a sadder vision yet : thine aged his hoary',
#   'the gods that is gone , no longer still , the that place no more can i have , that s to be as i never'],
#  ['locks with treacherous dost thou now doubt truth to be a wilt thou die , that hast forgot to smile ? nay ,',
#   'get thee hence ! leave all thy winsome the faint fragrance of thy scattered flowers : in holy silence wait the appointed days ,',
#   'to thee in this place , thou art with thy wings . come , let us be so much as as i . with a joy'],
#  ['and weep away the leaden - footed hours . t_up iii . the air is bright with hues of lightand rich with laughter and with',
#   'singing : young hearts beat high in ecstasy , and banners wave , and bells are ringing : but silence falls with fading day ,',
#   'do nt deal in lies , or being hated do nt give way to hating , and yet do nt look too good , nor',
#   'and that , death - long , and it all is still and the , as if the bellman had done : and then - you'],
#  ['talk too you can dream - and not make dreams your you can think - and not make thoughts your , if',
#   'you can meet with triumph and treat those two just the you can bear to hear the truth you ve by',
#   'you are not a , when you were as you have loved by me , i am not good , no longer the of , when'],
#  ['knaves to make a trap for fools , or watch the things you gave your life to , broken , and stoop and up',
#   'with worn - out you can make one heap of all your risk it on one turn of pitch - and - toss',
#   'the the of their and was when the wind was on your way , the and , the way you should have been so , you'],
#  [', and lose , and start again at your , and never breathe a word about your loss : if you can force your',
#   'heart and nerve and serve your turn long after they are gone , and so hold on when there is nothing in the',
#   'love , and you are not your , and you are not a heart in which the way you shall feel in the world of the'],
#  ['will which says to them : hold you can talk with crowds and keep your virtue , or walk with kings - nor lose',
#   'the common touch , if neither foes nor loving friends can hurt you , if all men count with you , but none too much',
#   ', and that is always , and all your love , and the life and the mind , and one is more than time in the'],
#  [': if you can fill the unforgiving sixty seconds worth of distance run , yours is the earth and everything that s in it',
#   ', and - which is more - you ll be a man , my son ! that i should have the let a',
#   ', but is it so ? it is not a the the . of your own life is not an to be a heart for you'],
#  ['red sword of into my heart , letting to the weeds of the sinful blood , what can you offer',
#   'flowery ? a hence with your red sword of virtue . as the blind miltons memory of light , the deaf phantasy',
#   'the world be in the first . when the world will be in the to the time . all things we , too , for you'],
#  ['of tone , joys for them all things known in our sphere of sound and so while the streets of',
#   'brick and stone with heat , noise , and dust from morn till night , i will give rein to fancy , taking flight',
#   'the , when , with a joy -- we may have to be , you know what are in this , the voice of joy ,'],
#  ['from dismal now and here , and dwell alone with new - senses . all day long , think ye t is i ,',
#   'who sit twixt darkened walls , while ye chase beauty over land and sea ? on wings of some rare poets song where the',
#   'and the thing must be done , it is the same to his heart will the night , when it was made of me , the'],
#  ['wide billow laughs and leaps and falls , i soar cloud - high , free as the winds are free . grasps the substance',
#   '? who mid shadows ? he who within some dark - bright wood , twixt sleep and waking , where the pines',
#   'of a , each one , but its as the your and i am not a - a - of any , and those or in'],
#  ['have his couch with soft brown sprays ? he notes not how the living water shines , trembling along the cliff , a',
#   'flickering haze , brimming a wine - bright pool , nor lifts his gaze to read the ancient wonders and the signs . does he',
#   'sea - a - a - in , his hearts may with his a , and the water - , the soul of summer is not'],
#  ['possess the actual , or do i , who paint on air more than his sense receives , the glittering pine - tufts with closed',
#   'eyes behold , breathe the strong perfume , see the sky quiver like azure flame between the leaves , and open unseen gates with',
#   ', and they are not like a the , who has been long ; thou hast not seen in the dark the world will make ,'],
#  ['key of gold ? the farmhouse lingers , though to the new city street it has to weara number in . but what',
#   'about the held the house as in an elbow - ask as one who knew the brook , its impulse , having',
#   'is the world with a dream . i ve heard it would be on this world . but i could you see it too much or'],
#  ['dipped a finger made it leap my , having flower to try its where they meadow grass could be cemented',
#   'downfrom growing under pavements of a apple trees be sent to hearth - stone water wood to serve a brook the else',
#   ', and a , with his love it is like a the the on this is . now is a dream in the dead . i'],
#  ['of an immortal longer needed ? staunch it at its loads dumped down ? the brook was in a sewer',
#   'dungeon under darkness still to live and run all for nothing it had ever forget to go in fear one',
#   ', and , as if he had not , but too much to be said , that s to be said and it , like a'],
#  ['would know except for ancient such a brook ran water . but i wonderif from its being kept forever under , the thoughts may',
#   'not have risen that so new - built city from both work and sleep . athwart the watch the moonbeams cast a',
#   'be the dead . i m not found the , all that had been , but do nt know the from that would have been ,'],
#  ['bright , so cold , so frail , that for a space it - frost on the margin of my raise my',
#   'head , --the splendid moon i see : then droop my head , and sink to dreams of thee fatherland , of thee !',
#   'soul , when the in earth is still the shadow of a and that is death . then alone the way is on his my ,'],
#  ['in the city set upon slime and they cry in their who goes home ? and there comes no answer in arch or',
#   'dome , for none in the city of graves goes home . yet these shall perish and understand , for god has pity on this',
#   ', and all is as a thing with that - a - my soul , when the you are , and let me here i have'],
#  ['great land . men that are men again ; who goes home ? and ! who goes home ? for there s blood',
#   'on the field and blood on the foam and blood on the body when man goes home . and a voice . . .',
#   ', and a little , but some time and the world will come back . night with fire -- the wind and the the , ,'],
#  ['who is for victory ? who is for liberty ? who goes home ? five months ago the stream did flow , the lilies bloomed',
#   'within the sedge , and we were lingering to and fro , where none will track thee in this snow , along the stream ,',
#   'of the the air of a the the to that time . when the being you did it be , with little the his , ,'],
#  ['beside the , sweet , be free to love and if i do not hear thy foot , the frozen river is as',
#   'mute , the flowers have dried down to the root : and why , since these be changed since may , shouldst thou change less',
#   'the world , the friend , you love shall be and you are not free . this is the same thing to be said , ,'],
#  ['than slow , slow as the winter tears have drifted to mine my poor cheeks , five months blushing at thy',
#   'praises so , put on for a , sweet , be free to praise and if my face is turned too pale',
#   'heart , and all that thou art , too much , all the the , and all the stars are not , the great for ,'],
#  [', it was thine oath that first did fail , was thy love proved false and frail , why , since these be',
#   'changed , should i change less than thou . the sovereign beauty which i do admire , witness the world how worthy to be',
#   ', a thing , and all to be said . all things have you see , your friend , and none , but could the ,'],
#  ['praised : the light whereof hath kindled heavenly firein my frail spirit , by her from baseness raised;that being now with her huge brightness dazed',
#   ', base thing i can no more endure to view;but looking still on her , i stand amazed at wondrous sight of so celestial hue.so',
#   ', she is not so in her : and she , so much as her it doth it -- i d . say for me in'],
#  ['when my tongue would speak her praises due , it stopped is with thoughts astonishment : and when my pen would write her titles true',
#   ', it ravishd is with fancys wonderment : yet in my heart i then both speak and write the wonder that my wit can not',
#   ', and when her face was no ; my soul in his own and i would have been my , who can not give my heart'],
#  ['endite',
#   '.',
#   ', and one is more than time for a moment when he was , but , and then a man said , the soul and a']]

# %%
def train_disc(disc, epochs, trn_dl, val_dl, opt):
    for epoch in range(epochs):
        with tqdm(total=len(trn_dl)) as pbar:
            disc.train()
            for p in disc.parameters(): p.data.clamp_(-0.01, 0.01)
            for i, ds in enumerate(trn_dl):
                x, y = ds
                disc.zero_grad()
                real_loss, _ = disc(x)
                fake_loss, _ = disc(y)
                disc_loss = (1 - real_loss + fake_loss).mean(0)
                disc_loss.backward()
                opt.step()
                pbar.update()
            print(f'Epoch {epoch}:')
            print(f'Loss_Real {real_loss.mean(0).data.item()}; Loss_Fake {fake_loss.mean(0).data.item()}; Loss_Disc {disc_loss.data.item()} ')
        disc.eval()
        for i, ds in enumerate(val_dl):
            x, y = ds
            real_loss, _ = disc(x)
            fake_loss, _ = disc(y)
            disc_loss = (1 - real_loss + fake_loss).mean(0)
        print(f'Val Loss_Real {real_loss.mean(0).data.item()}; Val Loss_Fake {fake_loss.mean(0).data.item()}; Loss_Disc {disc_loss.data.item()} ')

# %%
train_disc(disc, 5, trn_disc_dl, val_disc_dl, optimizerD)
# Out:
# 100%|█████████▉| 12491/12492 [12:13<00:00, 15.27it/s]Epoch 0:
# Loss_Real 1.0; Loss_Fake 1.3681117350117233e-10; Loss_Disc 8.358331626823201e-08
# 100%|██████████| 12492/12492 [12:13<00:00, 17.03it/s]
# Val Loss_Real 1.0; Val Loss_Fake 2.659799464010959e-11; Loss_Disc 2.659799464010959e-11
#   7%|▋         | 814/12492 [00:43<10:27, 18.61it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-169-4564a485103d> in <module>()
# ----> 1 train_disc(disc, 5, trn_disc_dl, val_disc_dl, optimizerD)
#
# <ipython-input-168-1e1c9af4e7d5> in train_disc(disc, epochs, trn_dl, val_dl, opt)
#       8                 disc.zero_grad()
#       9                 real_loss, _ = disc(x)
# ---> 10                 fake_loss, _ = disc(y)
#      11                 disc_loss = (1 - real_loss + fake_loss).mean(0)
#      12                 #gen_loss = vae_loss(fake,y,gen.kld_weight)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# <ipython-input-158-2e0e744c512a> in forward(self, inp, y)
#      27         hidden = self.initHidden(bs) # nl*bs*nh
#      28         emb = self.emb_enc_drop(self.emb_enc(inp)) #sl*bs*em_sz
# ---> 29         enc_out, (h_n, c_n) = self.gru_enc(emb,hidden) #enc_out: sl*bs*nh, hidden: nl*bs*nh
#      30         #classify
#      31         h_n = h_n.view(2,2,bs,-1).permute(0,2,1,3).contiguous().view(self.nl,bs,-1)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     190             flat_weight=flat_weight
#     191         )
# --> 192         output, hidden = func(input, self.all_weights, hx, batch_sizes)
#     193         if is_packed:
#     194             output = PackedSequence(output, batch_sizes)
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, *fargs, **fkwargs)
#     322             func = decorator(func)
#     323
# --> 324         return func(input, *fargs, **fkwargs)
#     325
#     326     return forward
#
# ~/projects/jadlg_rnn/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, weight, hx, batch_sizes)
#     286             batch_first, dropout, train, bool(bidirectional),
#     287             list(batch_sizes.data) if variable_length else (),
# --> 288             dropout_ts)
#     289
#     290         if cx is not None:
#
# KeyboardInterrupt:

# %%
torch.save(disc.state_dict(), PATH/'models/disc_en_5.h5')

# %%
disc.load_state_dict(torch.load(PATH/'models/disc_en_5.h5', map_location=lambda storage, loc: storage))

# %%
def ppx(input, target):
    sl, bs = target.size()
    sl_in,bs_in,nc = input.size()
    if sl>sl_in: input = F.pad(input, (0,0,0,0,0,sl-sl_in))
    input = input[:sl]
    return torch.exp(F.cross_entropy(input.view(-1,nc), target.view(-1)))

# %%
def train(gen, disc, epochs, trn_dl, val_dl, optimizerD, optimizerG, first=True):
    gen_iterations = 0
    
    for epoch in range(epochs):
        gen.train(); disc.train()
        n = len(trn_dl)
        #train loop
        with tqdm(total=n) as pbar:
            for i, ds in enumerate(trn_dl):
                d_iters = 20 if (first and (epoch < 2)) else 5
                g_iters = 20 if (first and (epoch < 2)) else 3
                x, y = ds
                sl, bs = x.size()
                for j in range(d_iters):
                    for p in disc.parameters(): p.data.clamp_(-0.01, 0.01)
                    gen.eval()
                    disc.train()
                    _,fake = gen(x, sampling=True)
                    disc.zero_grad()
                    fake_loss, _ = disc(V(fake))
                    real_loss, _ = disc(V(y))
                    disc_loss = (1 - real_loss +fake_loss).mean(0)
                    disc_loss.backward()
                    optimizerD.step()
                
                disc.eval(), gen.train()
                fake_, fake_sample = gen(x,y,sampling=True)
                fake = F.log_softmax(fake_,dim=2)
                reward_t, _ = disc(y)
                reward_f, attn_f = disc(fake_sample)
                missing = 1 - y==fake_sample
                gen.zero_grad()
                gen_loss = 0
                for i in range(sl):
                    for j in range(bs):
                        gen_loss += -fake[i,j,fake_sample[i,j]] * reward_f.squeeze(1)[j] #* attn_f[i,j]
                gen_loss = V(gen_loss, requires_grad=True)/bs
                gen_loss.backward()
                optimizerG.step()
                gen_iterations += 1
                pbar.update()
        print(f'Epoch {epoch}:')
        print(f'Loss_D {disc_loss.data.item()}; Loss_G {gen_loss.data.item()} Ppx {ppx(fake_,y)}')
        print(f'D_real {real_loss.mean(0).view(1).data.item()}; Loss_D_fake {fake_loss.mean(0).view(1).data.item()}')
        # val loop
        gen.eval(), disc.eval()
        for i, ds in enumerate(val_dl):
            x, y = ds
            sl, bs = x.size()
            gen_loss=0
            fake, fake_sample = gen(x, sampling=True)
            real_loss, _ = disc(y)
            fake_loss, attn_f = disc(fake_sample)
            disc_loss = (1-real_loss+fake_loss).mean(0)
            for i in range(sl):
                for j in range(bs):
                    gen_loss += -fake[i,j,fake_sample[i,j]] * fake_loss.squeeze(1)[j] #* attn_f[i,j]
        print(f'Loss_D_val {disc_loss.data.item()}; Loss_G_val {gen_loss.mean(0).data.item()} Ppx {ppx(fake,y)}')
        print(f'D_real_val {real_loss.mean(0).view(1).data.item()}; Loss_D_fake_val {fake_loss.mean(0).view(1).data.item()}')

# %%
gen.load_state_dict(torch.load(PATH/'models/seq2seq_en.h5', map_location=lambda storage, loc: storage)) 
disc.load_state_dict(torch.load(PATH/'models/disc_en.h5', map_location=lambda storage, loc: storage))

# %%
def produce_out_sampling(val_dl, model, use_cuda=True):
    model.eval()
    out = []
    loss = 0
    for i, ds in enumerate(val_dl):
        x, y = ds
        bptt, bs = x.size()
        y = y.view(bptt, bs)
        #x = x.long()
        if use_cuda:
            x = x.cuda()
        probs, sample = model(x, sampling=True)
        p = ppx(probs, y)
        preds = np.array(sample)
        for i in range(x.size(1)):
            seed = ' '.join([itos[o] for o in x[:,i] if o not in [0,1,2,3]])
            actual = ' '.join([itos[o] for o in y[:,i] if o not in [0,1,2,3]])
            fake = ' '.join([itos[o] for o in preds[:,i] if o not in [0,1,2,3]])
            out.append([seed,actual,fake])
    print(p.data.item())
    return out

# %%
torch.save(gen.state_dict(), PATH/'models/netG.h5')
torch.save(disc.state_dict(), PATH/'models/netD.h5')

# %%
gen.load_state_dict(torch.load(PATH/'models/netG.h5', map_location=lambda storage, loc: storage))
disc.load_state_dict(torch.load(PATH/'models/netD.h5', map_location=lambda storage, loc: storage))

# %%
out_gan2 = produce_out_sampling(val_gan_dl, gen)
out_gan = produce_out(val_gan_dl, gen)
pickle.dump(out_gan, (PATH/'v_gan_en.pkl').open('wb'))
# Out:
# 65609.6015625
# tensor(64036.4219, device='cuda:0', grad_fn=<ExpBackward>)

# %%
out_gan
# Out:
# [['i am hunting my wayward heart.i can feel that steady drum beat , following the ruby fingertips like , it to the',
#   'continually the heart flees , running from this only ardor can all know it is only must armor ourselves is',
#   'world , with the and , as the my soul , with joy and . . at the from of a , never could be ,'],
#  ['a on both sides -as you fall into love , and as you fall out -all the time while under its are like',
#   'on the single does not cut how soon hath time , the subtle thief of youth , on his wing my three',
#   'the the to you and day you will never meet the way of the and of his the , and the bellman in tell you ,'],
#  ['and year ! my days fly on full career , but my late spring no bud or blossom . perhaps my',
#   'might deceive the truth , that i to manhood am arrived so near , and inward doth much less appear , that some',
#   'love , and that is there ? no , but here is there to - day and be the same , that s not even no'],
#  ['more - happy spirits . yet be it less or more , or soon or slow , it shall be still in',
#   'measure even to that same lot , however mean or high , toward which time leads me , and the will of heaven ; all',
#   'the , great and light , and the other most , only other would come , we know all where he saw the and of him'],
#  ['is , if i have grace to use it so , as ever in my great eye . a t_up boat beneath a sunny',
#   'sky , lingering onward dreamilyin an evening of july --children three that nestle near , eager eye and willing ear , pleased a simple tale',
#   ', i heard a voice -- yet i could but be done , i m with you in rockland where you are free , but the'],
#  ['to hear --long has paled that sunny sky : echoes fade and memories die : autumn frosts have slain july.still she haunts me , phantomwise',
#   ', alice moving under skiesnever seen by waking eyes.children yet , the tale to hear , eager eye and willing ear , lovingly shall nestle',
#   ', and a , to be a , so long , but , if they meet to their heart , for even the to the ,'],
#  ['near.in a wonderland they lie , dreaming as the days go by , dreaming as the summers die : ever drifting down the stream --lingering',
#   'in the golden dream --life , what is it but a dream ? my sleeping children are still flying dreams in their goose - down',
#   'the world the rain - in the morning , sky and the wind to the rain , we know not what the world will be like'],
#  ['heads . the of the river singing morning songs fish watch their turn sun - white . the grey - green',
#   ', like hair points the waters drift . all is morning hush and bird beautiful . five months ago the stream did',
#   'the the the the the the the the that is of the the the , whose eyes are the the dead that s a the ,'],
#  ['flow , the lilies bloomed within the sedge , and we were lingering to and fro , where none will track thee in this snow',
#   ', along the stream , beside the , sweet , be free to love and if i do not hear thy foot ,',
#   ', and when the waves are made , as the clouds of our love , we are not long , and be the thing in which'],
#  ['the frozen river is as mute , the flowers have dried down to the root : and why , since these be changed since may',
#   ', shouldst thou change less than slow , slow as the winter tears have drifted to mine my poor cheeks , five',
#  ['to the world proportion ye revealed , that every being joyfully obeys ,-- a boundless structure , in nights veil concealed , illumed by naught',
#   'but faint and languid rays , a band of phantoms , struggling ceaselessly , holding his mind in slavish fetters bound , unsociable and rude',
#   ', a voice of a dead . his voice of stars , the the , of out of fire , the only life as out of'],
#  ['as be , assailing him on every side around ,-- thus seemed to man creation in that day!united to surrounding forms aloneby the blind chains',
#   'the passions had put on , whilst natures beauteous spirit fled awayunfelt , untasted , and unknown.and , as it hovered oer with parting ray',
#   ', with in - fire did from , from the ocean - of eyes -- the last - born ever - shall , where the ,'],
#  [', ye seized the shades so neighborly , with silent hand , with feeling mind , and taught how they might be combinedin one firm',
#   'bond of harmony.the gaze , light - soaring , felt uplifted then , when first the cedars slender trunk it viewed;and pleasingly the oceans crystal',
#   ', and , as the as first - and he went , and found the way we did not see , but its as a child'],
#  ['floodreflected back the dancing form again.could ye mistake the look , with beauty fraught , that nature gave to help ye on your way?the image',
#   'floating on the billows taughtthe art the fleeting shadow to portray.from her own being torn apart , her phantom , beauteous as a dream ,',
#   ', the best , with a mind to - day , to the child to say to her , i , her , her , face'],
#  ['she plunged into the silvery stream , surrendering to her spoilers art.creative power soon in your breast unfolded;too noble far , not idly to conceive',
#   ', the shadows form in sand , in clay ye moulded , and made it in the sketch its being leave.the longing thirst for action',
#   ', the to the , there , in all the , then , the my to the , , were now that we to find ,'],
#  ['then awoke ,-- and from your breast the first creation broke.by contemplation captive made , ensnared by your discerning eye , the friendly phantoms soon',
#   'betrayedthe talisman that roused your ecstasy.the laws of wonder - working might , the stores by beauty brought to light , inventive reason in soft',
#   ', the , from his , black as a dead heart is , by a love the soul is still , and still the voice is'],
#  ['union plannedto blend together neath your forming hand.the obelisk , the pyramid ascended , the hermes stood , the column sprang on high , the',
#   'reed poured forth the woodland melody , immortal song on victors deeds attended.the fairest flowers that decked the earth , into a nosegay , with',
#   'light of the that , like life & gold , the as first a thing of , and all the , light on his all ,'],
#  ['wise choice combined , thus the first art from nature had its birth;into a garland then were nosegays twined , and from the works that',
#   'mortal hands had made , a second , nobler art was now displayed.the child of beauty , self - sufficient now , that issued from',
#   'is in his own , and all that s to be a thing that , with my mind , with that mind , that fire ,'],
#  ['your hands to perfect day , loses the chaplet that adorned its brow , soon as reality asserts its sway.the column , yielding to proportions',
#   'chains , must with its sisters join in friendly link , the hero in the hero - band must sink , the muses harp peals',
#   ', the shadow , and all the shadows in the many - black the stars will the be , if in some morning the , sea'],
#  ['forth its tuneful strains.the wondering savages soon cameto view the new creations planbehold!--the joyous crowds exclaim ,-- behold , all this is done by man!with',
#   'jocund and more social aimthe minstrels lyre their awe awoke , telling of titans , and of giants fraysand lion - slayers , turning ,',
#   'of their in , and the ocean of god , and the the , and the , as in being he , and on high ,'],
#  ['as he spoke , even into heroes those who heard his lays.for the first time the soul feels joy , by raptures blessed that calmer',
#   'are , that only greet it from afar , that passions wild can neer destroy , and that , when tasted , do not cloy.and',
#   ', to him to whom we love , to keep the world from , i , as he looked , the first - time , ,'],
#  ['now the spirit , free and fair , awoke from out its sensual sleep;by you unchained , the slave of careinto the arms of joy',
#   'could leap.each brutish barrier soon was set at naught , humanity first graced the cloudless brow , and the majestic , noble stranger , thought',
#   ', the to be a sea , a , to his in life , the the , the the , the the morning , there ,'],
#  [', from out the wondering brain sprang boldly now.man in his glory stood upright , and showed the stars his kingly face;his speaking glance the',
#   'suns bright lightblessed in the realms sublime of space.upon the cheek now bloomed the smile , the voices soulful harmonyexpanded into song the while ,',
#   'the , with their a , were the first of the first , were all his way to his , then , with joy did not'],
#  ['and feeling swam in the moist eye;and from the mouth , with spirit teeming oer , jest , sweetly linked with grace , began to',
#   'pour.sunk in the instincts of the worm , by naught but sensual lust possessed , ye recognized within his breastlove - spirituals noble germ;and that',
#   'the , from the sea - , out of the , & his , as oer the first time & , & yet great tears ,'],
#  ['this germ of love so blestescaped the senses abject load , to the first pastoral song he owed.raised to the dignity of thought , passions',
#   'more calm to flow were taughtfrom the bards mouth with melody.the cheeks with dewy softness burned;the longing that , though quenched , still yearned ,',
#   'in such a , thou art to , with thy love at all , the great , as if the first were all , then into'],
#  ['proclaimed the spirit-harmony.the wisests wisdom , and the strongests vigor ,-- the meekests meekness , and the noblests grace , by you were knit together',
#   'in one figure , wreathing a radiant glory round the place.man at the unknowns sight must tremble , yet its refulgence needs must love;that mighty',
#   ', and with a mighty arms he , thou , & the last black be , its last , then their and , if his from'],
#  ['being to resemble , each glorious hero madly strove;the prototype of beautys earliest strainye made resound through natures wide domain.the passions wild and headlong course',
#   ', the ever - varying plan of fate , duty and instincts twofold force , with proving mind and guidance straightye then conducted to their',
#   ', and , and all the you are the great from the feet , & , and , with your friend , the the , are'],
#  ['ends.what nature , as she moves along , far from each other ever rends , become upon the stage , in song , members of',
#   'order , firmly bound.awed by the furies chorus dread , murder draws down upon its headthe doom of death from their wild sound.long eer the',
#   'the , with his name , its love the in - spring , where the waves with hearts of as thou art , with the world'],
#  ['wise to give a verdict dared , an iliad had fates mysteries declaredto early ages from afar;while providence in silence faredinto the world from thespis',
#   'car.yet into that worlds current so sublimeyour symmetry was borne before its time , when the dark hand of destinyfailed in your sight to part',
#   'the the one to be a thing to - the , , when the rain had been , the first man on the world , when'],
#  ['by force.what it had fashioned neath your eye , in darkness life made haste to die , ere it fulfilled its beauteous course.then ye with',
#   'bold and self - sufficient mightled the arch further through the futures night : then , too , ye plunged , without a fear ,',
#   'the a , - by - a - it came , we , too , into our own when i could , your little heart life'],
#  ['into avernus ocean black , and found the vanished life so dearbeyond the urn , and brought it back.a blooming pollux - form appeared now',
#   'soon , on castor leaning , and enshrined in light -- the shadow that is seen upon the moon , ere she has filled her',
#   ', and that , in its life , the bellman in their feet , each , too , no , no longer can to see ,'],
#  ['silvery circle bright!yet higher ,-- higher still above the earthinventive genius never ceased to rise : creations from creations had their birth , and harmonies',
#   'from harmonies.what here alone enchants the ravished sight , a nobler beauty yonder must obey;the graceful charms that in the nymph unite , in the',
#   ', and his , thus it , as he knows he can , the to be happy , it seems , a voice of to ,'],
#  [', the sunsets light ,-- thus gleams , lifes barren pathway over , poesys shadowy world so bright.in bridal dress ye led us onbefore the',
#   'terrible unknown , before the inexorable fate , as in your urns the bones are laid , with beauteous magic veil ye shadethe chorus dread',
#   'world - the in - its . where the waves were to that , when the waves were made of in the when - wide ,'],
#  ['that cares create.thousands of years i hastened throughthe boundless realm of vanished timehow sad it seems when left by you -- but where ye linger',
#   ', how sublime!she who , with fleeting wing , of yorefrom your creating hand arose in might , within your arms was found once more',
#   ', and , as if the waves are made of dear , when the world is still , for she has been more , when the'],
#  [', when , vanquished by times silent flight , lifes blossoms faded from the cheek , and from the limbs all vigor went , and',
#   'mournfully , with footstep weak , upon his staff the gray - beard leant.then gave ye to the languishing , lifes waters from a new',
#   'the last , the to be up , he heard with a god , who lost the , from him a dream out from his head'],
#  ['- born spring;twice was the youth of time renewed , twice , from the seeds that ye had strewed.when chased by fierce barbarian hordes away',
#   ', the last remaining votive brand ye torefrom orients altars , now pollutions prey , and to these western lands in safety bore.the fugitive from',
#   ', and the , as if they were , and even the it came out of his , and from my breast the soul ’s ,'],
#  ['yonder eastern shore , the youthful day , the west her dwelling made;and on hesperias plains sprang up once moreionias flowers , in pristine bloom',
#   'arrayed.over the spirit fairer nature shed , with soft refulgence , a reflection bright , and through the graceful soul with stately treadadvanced the mighty',
#   ', and , with the , days , light , with summer lost , and on thee now the day , with , with tears ,'],
#  ['deity of light.millions of chains were burst asunder then , and to the slave then human laws applied , and mildly rose the younger race',
#   'of men , as brethren , gently wandering side by side , with noble inward ecstasy , the bliss imparted ye receive , and in',
#   ', and , with a , - as in vain ! through he did not give , then back in the , when the in ,'],
#  ['the veil of modesty , with silent merit take your leave.if on the paths of thought , so freely given , the searcher now with',
#   'daring fortune stands , and , by triumphant paeans onward driven , would seize upon the crown with dauntless hands -- if he with grovelling',
#   'the , which , as my soul , the soul of death , in the mighty arms of he , while he has made a man'],
#  ['hirelings paythinks to dismiss his glorious guide -- or , with the first slaves - place arrayart near the throne his dream supplied -- forgive',
#   'him!--oer your head to - dayhovers perfections crown in pride , with you the earliest plant spring had , soul - forming nature first began;with',
#   'to the heart , who the soul to - day , to - , the with it were light , where was the it , before'],
#  ['you , the harvest - chaplet glad , perfected nature ends her plan.the art creative , that all - modestly arosefrom clay and stone ,',
#   'with silent triumph throwsits arms around the spirits vast domain.what in the land of knowledge the discoverer knows , he knows , discovers , only',
#   'and in the mighty arms she of the mountain , the blue , the the , the the , the , , - the , ,'],
#  ['for your gainthe treasures that the thinker has amassed , he will enjoy within your arms alone , soon as his knowledge , beauty -',
#   'ripe at last.to art ennobled shall have grown ,-- soon as with you he scales a mountain - height , and there , illumined by',
#   ', and , with truth , and , from all the world & the by , where the water ’s all , the world from ,'],
#  ['the setting sun , the smiling valley bursts upon his sight.the richer ye reward the eager gazethe higher , fairer orders that the mindmay traverse',
#   'with its magic rays , or compass with enjoyment unconfined -- the wider thoughts and feelings open lieto more luxuriant floods of harmony.to beautys richer',
#   'of a , whose tears are a in this , who on thee i , a voice -- to be a thing with of , ,'],
#  [', more majestic stream ,-- the fair members of the worlds vast scheme , that , maimed , disgrace on his creation bring , he',
#   'sees the lofty forms then perfecting -- the fairer riddles come from out the night -- the richer is the world his arms enclose ,',
#   ', with his life - blood it did not see the , from his face the most - its the , his soul was , by'],
#  ['the broader stream the sea with which he flows -- the weaker , too , is destinys blind might -- the nobler instincts does he',
#   'prove -- the smaller he himself , the greater grows his love.thus is he led , in still and hidden race , by poetry ,',
#   ', the , from his , the first , the gods in living is the eye , and to his heart the soul is , ,'],
#  ['who strews his path with flowers , through ever - purer forms , and purer powers , through ever higher heights , and fairer grace.at',
#   'length , arrived at the ripe goal of time ,-- yet one more inspiration all - sublime , poetic outburst of mans latest youth ,',
#   ', the one , by night he loved his way , he went , as though , their last blue , the first , his before'],
#  ['and -- he will glide into the arms of truth!herself , the gentle cypria , illumined by her fiery crown , then stands before her',
#   'full - grown sonunveiled -- as great urania;the sooner only by him caught , the fairer he had fled away!thus stood , in wonder rapture',
#   ', as she was made of him , as his , as through his first , the first , the first one eye can the ,'],
#  ['- fraught , ulysses noble son that day , when the sage mentor who his youth beguiled;herself transfigured as joves glorious child!mans honor is confided',
#   'to your hand ,-- there let it well protected be!it sinks with you ! with you it will expand!poesys sacred sorceryobeys a world - plan',
#   'to the , if they hear it no longer a thing in which the days have heard the in of your the the world was ,'],
#  ['wise and good;in silence let it swell the floodof mighty - rolling harmony.by her own time viewed with disdain , let solemn truth in song',
#   'remain , and let the muses band defend her!in all the fullness of her splendor , let her survive in numbers glorious , more dread',
#   'of the earth , and from her it be the world , with silent hand , the first - shadow of beauty , when all ,'],
#  [', when veiled her charms appear , and vengeance take , with strains victorious , on her tormentors ear!the freest mothers children free , with',
#   'steadfast countenance then riseto highest beautys radiancy , and every other crown despise!the sisters who escaped you here , within your mothers arms yell meet;what',
#   'the sea and a , to feel the the a dead he , who , where , or the other , as if the first time'],
#  ['noble spirits may revere , must be deserving and complete.high over your own course of timeexalt yourselves with pinion bold , and dimly let your',
#   'glass sublimethe coming century unfold!on thousand roads advancing fastof ever - rich variety , with fond embraces meet at lastbefore the throne of harmony!as into',
#   'soul the in thy love - and , when the soul ’s great to , and all the you are as a the the , from'],
#  ['seven mild rays we viewwith softness break the glimmer white , as rainbow - beams of sevenfold huedissolve again in that soft light , in',
#   'clearness thousandfold thus throwyour magic round the ravished gaze ,-- into one stream of light thus flow ,-- one bond of truth that neer decays',
#   'the sea - wind , the spirit , and sea - moon , far far from those bright , the dark - world which , ,'],
#  ['! good - night ? ah ! no ; the hour is those it should us remain together still , then it',
#   'will be good can i call the lone night good , though thy sweet wishes wing its it not said , thought ,',
#   'is not a word . this is the same that one . where the voice of the the to be — and the that must be'],
#  ['understood it will be -- good hearts which near each other evening close to morning light , the night is good ;',
#   'because , my love , they never say good - night some of us would have conceived out of our own no',
#   'and he will come back in the , , and all the soul of the the , of the the , were the best , from'],
#   ', and the sky is not a the the to that time when i heard this you are still with me , and i will never'],
#  ['thin wood stirs in its sleep and then is still ( like age ) at the winds shadow follows my footsteps',
#   'where i go , a giant on the where the rivers arms are wound , and icy cling , there comes to',
#   ', and all is still . for sea - bird are not a - a , and the other will the in of this the ,'],
#  ['me as in a a far - off clear , thin , vibrant the distant of frost - elves as they come',
#   'and go , , in silver chains , his stand upon the hills bleak crest and note the far night world : the',
#   ', and that is it ? no longer a the , whose eyes are it so much for me , the shadow of my love ,'],
#  ['mighty lake whose passionate breast , into rest , in sleep is : the heavens whose wondrous host wheel white',
#   'from flaming coast to down the nights dim luminous ways , they come once more , those great star - watchers of old',
#   ', and all are made to - day , to - night to be . now it too , for all the time to be ,'],
#  ['days the lonely , calm - ones , whose still gaze , on old - time , orient shore , dreamed in the wheeling sons',
#   'of light , the awful secrets of earths come , those lofty ones of old , and take me by the hand , and',
#   ', and the only one . down the black - shadow of the , were of that great for all the dead , that in ,'],
#  ['call me brother ; ages rolled are but a smoke - mist ; kindred - , they lift me to their lights that',
#   'from pale shine , their clear eyes look with peace on language of no common watchers speak to thoughts the depths',
#   'the sun was gone , and then was left to me ; and , when at last i saw , we know not for what ,'],
#  ['of heaven plummets true . it were a spend with them one holy hour , and know their love and grasp their',
#   'wrapt around with glad content , i learn with soul serene , caught from the beauty that is earth , the heavens luminous',
#   'soul , and not not is to say , does it last well that we have heard the to of their and as , when the'],
#  ['tent , the frost - lit dreams between , and something holier out of sight , glad visions of the backward past the sere',
#   'hills breast , the spectral moaning wood , with great peace brooding in my breast , i turn me toward the common earths worn',
#   ', and when i took the first the gods or my , which they were so dear as this - to - . , as the'],
#  ['as i pass , a sacred sign , each lays his holy lips on mine :-- gives me the golden of song ,',
#   'tips my hushed heart with high in heaven i hear that march in mystic paths along , great , the lyre ,',
#   'and , as if the sun were light , the my , most , while the world doth with our and , and the other ,'],
#  ['the - of the ages swell , to earth - tuned ear . it is a sultry day ; the sun has',
#   'drank the dew that lay upon the morning grass , there is no rustling in the lofty elm that canopies my dwelling , and its',
#   'heard on the , the blue and the moon , all the stars and i have , it is with the and of the heart from'],
#  ['shade scarce cools me . all is silent , save the faint and interrupted murmur of the bee , settling on the sick flowers ,',
#   'and then again instantly on the wing . the plants around feel the too potent fervors ; the tall maize rolls up its long green',
#   'and still as a voice above me , the clouds and , and now the clouds will , where the moon - green the it ,'],
#  ['leaves ; the clover droops its tender foliage , and declines its blooms . but far in the fierce sunshine tower the hills , with',
#   'all their growth of woods , silent and stern , as if the scortching heat and dazzling light were but an element they loved .',
#   'the the , and with their the the , and the voice of the , and with a smile in the sea - blood , the'],
#  ['bright clouds , motionless pillars of the brazen heaven;-- their bases on the mountains -- their white tops shining in the far ether -- fire',
#   'the air with a reflected radiance , and make turn the gazers eye away . for me , i lie languidly in the shade ,',
#   'the the to the i in the to - night . then , ye are at this -- sleep in the sweet not , from from'],
#  ['where the thick turf , yet virgin from the kisses of the sun , retains some freshness , and i woo the wind that still',
#   ', and now it seems , when ever i loved with a heart , is just to - night . it had never been so ;'],
#  ['left at a ’s rich man said , ‘ my son shall bea lordly ruler o’er land and sighed , ‘',
#   '’tis the good god ’s i have another mouth to rich man ’s son grew strong and fair , and proud with the',
#   'and , with a little and of his that , when the bellman would all alone , he would have come in , and then said'],
#  ['pride of a motto in life was , ‘ live while you may , he crowded years in a single day.he bought position',
#   'and name and place , and he bought him a wife with a handsome journeyed over the whole wide world , but discontent his',
#   ', the only one who was , now were a thing to - the it was , then how to his it still , he ,'],
#  ['heart lay a serpent hidden in leaves and moss , and life seemed hollow and gold was scoffed at woman , and doubted',
#   'god , and died like a beast and went back to the son of the the soil , and god daily',
#   ', i think in the old man of the the to which i ve heard it may , with which you think as a with ,'],
#  ['for health and for love in his youthful prime , and two lives in tune and wants were simple , and',
#   'simple his creed , to trust god fully : it served his need , and lightened his labour , and him to a',
#   'to be a thing in , the very same , and now was was , , when the first had been , it seemed too ,'],
#  ['smile on his lips and a hope in his all is over and all is done , now which of these men was the',
#   'richer one ? tread lightly , she is the snow , speak gently , she can hearthe daisies her bright golden with',
#   'world , the first , like time to the and . when the sky was done , said the , and all that stars are no'],
#  ['rust , she that was young and to , white as snow , she hardly was a woman , she',
#   ', heavy stone , lie on her breast , i my heart alone , she is at , peace , she can not',
#   'not the world can not be to be , and you are not a - , when the beaver all , and then the , ,'],
# ...
#  ['wrath ; and here one offered to a thirsty words half - drowned amid those thunders frozen ( there were many',
#   'tooth - ache in each . there comes a happy pause , for human not endure to dance without every one must',
#   'the , by the the , are the in his . all this is still with that night , but at that time for the ,'],
#  ['reach the point at absolute . at such a moment ladies learn to give , to who would urge them over -',
#   'much , a flat and yet decided love such . there comes a welcome - hope revives , and fading eyes grow',
#   ', to the , then with one and , and all the same that did . where the voice are to be and are all before'],
#  ['bright , and pulses quicken : incessant pop the , and busy the tongue and chicken . flushed with new life , the',
#   'crowd flows back again : and all is tangled talk and mazy motion like a waving field of golden grain , or a tempestuous',
#   'world - the , are , o - a , - , where the bellman down , and only the way ’s first , now before'],
#  ['ocean . and thus they give the time , that nature peaceful sleep and snores , to ceaseless and mindless waste',
#   'of shoes and floors . and one ( we name him not ) that flies the flowers , that the dances , and that',
#   ', and the , from the the , which we look and was , with this life - in , and are not a the from'],
#  ['shuns the , they doom to pass in solitude the hours , writing - ballads . how late it grows ! the hour',
#   'is surely should have us with its double twilight wanes , and morning comes at last , uncle , what s',
#   'of the gods is for a heart that s to see it on the dark the morning - then come at home , and you ,'],
#  ['oclock ? the uncle gravely nods , and wisely t_up may mean much , but how is one to opens his mouth -',
#   'yet out of it , methinks , no words of wisdom flow . ii empress of art , for thee i wreath with all',
#   ', and now - it was all - the - , are the thing of he with , and his the , when the bellman ,'],
#  ['too slender my muse each halting line , and for the deed accept the will ! o day of tears ! whence comes this',
#   'spectre grim , parting , like deaths cold river , souls that not he bound to thee , as thou to him , by',
#   ', and not even to keep my friend , when the last way of a the . where the you are , and you are not'],
#   'outcry was a laugh , as he swung toward them holding up the in appeal , but half as if to keepthe life',
#   ', the beaver , the the , and then was to - the - you are well - of have in his and , when he'],
#  ['from spilling . then the boy saw all — since he was old enough to know , big a man ’s work , though',
#   'a child at heart — he saw all spoiled . ‘ do n’t let him cut my hand off — the doctor , when he',
#   'the only one who the first , as if he had been a - a - in his to , and the bellman d done ,'],
#  ['comes . do n’t let him , . but the hand was gone doctor put him in the dark of lay and',
#   'puffed his lips out with his then — the watcher at his pulse took one believed . they listened at his that',
#   'the the , and the beaver , with the to that day i saw it all the the on which was one out of the dead'],
#  ['ended more to build on there . and they , since not the one dead , turned to their affairs . if you',
#   'can keep your head when all about losing theirs and it on you can trust yourself when all men doubt you ,',
#   'was , with all the time and to his , , when the bellman looked street , and the was at the the and , ,'],
#  ['but make for their doubting too : if you can wait and not be tired by waiting , or , being lied about ,',
#   'do nt deal in lies , or being hated do nt give way to hating , and yet do nt look too good , nor',
#   'and that , death - long , and it all is still and the , as if the bellman had done : and then - you'],
#  ['talk too you can dream - and not make dreams your you can think - and not make thoughts your , if',
#   'you can meet with triumph and treat those two just the you can bear to hear the truth you ve by',
#   'you are not a , when you were as you have loved by me , i am not good , no longer the of , when'],
#  ['knaves to make a trap for fools , or watch the things you gave your life to , broken , and stoop and up',
#   'with worn - out you can make one heap of all your risk it on one turn of pitch - and - toss',
#   'the the of their and was when the wind was on your way , the and , the way you should have been so , you'],
#  [', and lose , and start again at your , and never breathe a word about your loss : if you can force your',
#   'heart and nerve and serve your turn long after they are gone , and so hold on when there is nothing in the',
#   'love , and you are not your , and you are not a heart in which the way you shall feel in the world of the'],
#  ['will which says to them : hold you can talk with crowds and keep your virtue , or walk with kings - nor lose',
#   'the common touch , if neither foes nor loving friends can hurt you , if all men count with you , but none too much',
#   ', and that is always , and all your love , and the life and the mind , and one is more than time in the'],
#  [': if you can fill the unforgiving sixty seconds worth of distance run , yours is the earth and everything that s in it',
#   ', and - which is more - you ll be a man , my son ! that i should have the let a',
#   ', but is it so ? it is not a the the . of your own life is not an to be a heart for you'],
#  ['red sword of into my heart , letting to the weeds of the sinful blood , what can you offer',
#   'flowery ? a hence with your red sword of virtue . as the blind miltons memory of light , the deaf phantasy',
#   'the world be in the first . when the world will be in the to the time . all things we , too , for you'],
#  ['of tone , joys for them all things known in our sphere of sound and so while the streets of',
#   'brick and stone with heat , noise , and dust from morn till night , i will give rein to fancy , taking flight',
#   'the , when , with a joy -- we may have to be , you know what are in this , the voice of joy ,'],
#  ['from dismal now and here , and dwell alone with new - senses . all day long , think ye t is i ,',
#   'who sit twixt darkened walls , while ye chase beauty over land and sea ? on wings of some rare poets song where the',
#   'and the thing must be done , it is the same to his heart will the night , when it was made of me , the'],
#  ['wide billow laughs and leaps and falls , i soar cloud - high , free as the winds are free . grasps the substance',
#   '? who mid shadows ? he who within some dark - bright wood , twixt sleep and waking , where the pines',
#   'of a , each one , but its as the your and i am not a - a - of any , and those or in'],
#  ['have his couch with soft brown sprays ? he notes not how the living water shines , trembling along the cliff , a',
#   'flickering haze , brimming a wine - bright pool , nor lifts his gaze to read the ancient wonders and the signs . does he',
#   'sea - a - a - in , his hearts may with his a , and the water - , the soul of summer is not'],
#  ['possess the actual , or do i , who paint on air more than his sense receives , the glittering pine - tufts with closed',
#   'eyes behold , breathe the strong perfume , see the sky quiver like azure flame between the leaves , and open unseen gates with',
#   ', and they are not like a the , who has been long ; thou hast not seen in the dark the world will make ,'],
#  ['key of gold ? the farmhouse lingers , though to the new city street it has to weara number in . but what',
#   'about the held the house as in an elbow - ask as one who knew the brook , its impulse , having',
#   'is the world with a dream . i ve heard it would be on this world . but i could you see it too much or'],
#  ['dipped a finger made it leap my , having flower to try its where they meadow grass could be cemented',
#   'downfrom growing under pavements of a apple trees be sent to hearth - stone water wood to serve a brook the else',
#   ', and a , with his love it is like a the the on this is . now is a dream in the dead . i'],
#  ['of an immortal longer needed ? staunch it at its loads dumped down ? the brook was in a sewer',
#   'dungeon under darkness still to live and run all for nothing it had ever forget to go in fear one',
#   ', and , as if he had not , but too much to be said , that s to be said and it , like a'],
#  ['would know except for ancient such a brook ran water . but i wonderif from its being kept forever under , the thoughts may',
#   'not have risen that so new - built city from both work and sleep . athwart the watch the moonbeams cast a',
#   'be the dead . i m not found the , all that had been , but do nt know the from that would have been ,'],
#  ['bright , so cold , so frail , that for a space it - frost on the margin of my raise my',
#   'head , --the splendid moon i see : then droop my head , and sink to dreams of thee fatherland , of thee !',
#   'soul , when the in earth is still the shadow of a and that is death . then alone the way is on his my ,'],
#  ['in the city set upon slime and they cry in their who goes home ? and there comes no answer in arch or',
#   'dome , for none in the city of graves goes home . yet these shall perish and understand , for god has pity on this',
#   ', and all is as a thing with that - a - my soul , when the you are , and let me here i have'],
#  ['great land . men that are men again ; who goes home ? and ! who goes home ? for there s blood',
#   'on the field and blood on the foam and blood on the body when man goes home . and a voice . . .',
#   ', and a little , but some time and the world will come back . night with fire -- the wind and the the , ,'],
#  ['who is for victory ? who is for liberty ? who goes home ? five months ago the stream did flow , the lilies bloomed',
#   'within the sedge , and we were lingering to and fro , where none will track thee in this snow , along the stream ,',
#   'of the the air of a the the to that time . when the being you did it be , with little the his , ,'],
#  ['beside the , sweet , be free to love and if i do not hear thy foot , the frozen river is as',
#   'mute , the flowers have dried down to the root : and why , since these be changed since may , shouldst thou change less',
#   'the world , the friend , you love shall be and you are not free . this is the same thing to be said , ,'],
#  ['than slow , slow as the winter tears have drifted to mine my poor cheeks , five months blushing at thy',
#   'praises so , put on for a , sweet , be free to praise and if my face is turned too pale',
#   'heart , and all that thou art , too much , all the the , and all the stars are not , the great for ,'],
#  [', it was thine oath that first did fail , was thy love proved false and frail , why , since these be',
#   'changed , should i change less than thou . the sovereign beauty which i do admire , witness the world how worthy to be',
#   ', a thing , and all to be said . all things have you see , your friend , and none , but could the ,'],
#  ['praised : the light whereof hath kindled heavenly firein my frail spirit , by her from baseness raised;that being now with her huge brightness dazed',
#   ', base thing i can no more endure to view;but looking still on her , i stand amazed at wondrous sight of so celestial hue.so',
#   ', she is not so in her : and she , so much as her it doth it -- i d . say for me in'],
#  ['when my tongue would speak her praises due , it stopped is with thoughts astonishment : and when my pen would write her titles true',
#   ', it ravishd is with fancys wonderment : yet in my heart i then both speak and write the wonder that my wit can not',
#   ', and when her face was no ; my soul in his own and i would have been my , who can not give my heart'],
#  ['endite',
#   '.',
#   ', and one is more than time for a moment when he was , but , and then a man said , the soul and a']]

# %%
out_gan = pickle.load((PATH/'v_gan_en.pkl').open('rb'))

# %%
out_gan2
# Out:
# [['i am hunting my wayward heart.i can feel that steady drum beat , following the ruby fingertips like , it to the',
#   'continually the heart flees , running from this only ardor can all know it is only must armor ourselves is',
#   'comes , sweet she , about a unless they gentle some being man and a climb to make a above the each after . still'],
#  ['a on both sides -as you fall into love , and as you fall out -all the time while under its are like',
#   'on the single does not cut how soon hath time , the subtle thief of youth , on his wing my three',
#   'when the wound is many time go home to - night with die or world , whom after nature is by thou hast . make'],
#  ['and year ! my days fly on full career , but my late spring no bud or blossom . perhaps my',
#   'might deceive the truth , that i to manhood am arrived so near , and inward doth much less appear , that some',
#   'laugh at this whose seven alone above the summer , better one to about had hunt the beat and fair , save i all in'],
#  ['more - happy spirits . yet be it less or more , or soon or slow , it shall be still in',
#   'measure even to that same lot , however mean or high , toward which time leads me , and the will of heaven ; all',
#   'mercy of the world , fell simply , a heroic you watch through far take , too that count , and what others better she'],
#  ['is , if i have grace to use it so , as ever in my great eye . a t_up boat beneath a sunny',
#   'sky , lingering onward dreamilyin an evening of july --children three that nestle near , eager eye and willing ear , pleased a simple tale',
#   'path , through the think that sun had feel a i go on then go caught to the how light , for his runs desire'],
#  ['to hear --long has paled that sunny sky : echoes fade and memories die : autumn frosts have slain july.still she haunts me , phantomwise',
#   ', alice moving under skiesnever seen by waking eyes.children yet , the tale to hear , eager eye and willing ear , lovingly shall nestle',
#   'it years now ; to have a sat doom , that wondrous sleep , thy already love did afterwards , i stands into this'],
#  ['near.in a wonderland they lie , dreaming as the days go by , dreaming as the summers die : ever drifting down the stream --lingering',
#   'in the golden dream --life , what is it but a dream ? my sleeping children are still flying dreams in their goose - down',
#   'it heavy , the oceans watched the hast the sunshine , like a street down among the mother , dark than the sun , twas'],
#  ['heads . the of the river singing morning songs fish watch their turn sun - white . the grey - green',
#   ', like hair points the waters drift . all is morning hush and bird beautiful . five months ago the stream did',
#   'the dread red pleasant the hundred father hours to come among soft young me , and will i take that door will perfect --- all'],
#  ['flow , the lilies bloomed within the sedge , and we were lingering to and fro , where none will track thee in this snow',
#   ', along the stream , beside the , sweet , be free to love and if i do not hear thy foot ,',
#   ', and beside all , she up , whose thy lord slowly that then through the out of this golden sure world will be you'],
#  ['the frozen river is as mute , the flowers have dried down to the root : and why , since these be changed since may',
#   ', shouldst thou change less than slow , slow as the winter tears have drifted to mine my poor cheeks , five',
#   'tell me , thus people far away with seared street ; to one life not too since there said is fresh ; deep back ,'],
#  ['months blushing at thy praises so , put on for a , sweet , be free to praise and if my',
#   'face is turned too pale , it was thine oath that first did fail , was thy love proved false and frail ,',
#   'beauty his air haste to before , and no stars can choose to be do i like not . would venus nights and field and'],
#  ['why , since these be changed , should i change less than thou . too my father got up put his clothes',
#   'on in the cold , then with cracked hands that labor in the weather fires blaze . no one ever',
#   'to find be suddenly first . here i was ,-- remark , friend , have ,— not did -- when by that night was dazzling :'],
#  ['wake and hear the cold , the rooms were warm , he d call , and slowly i would rise and dress',
#   ', fearing the chronic of that house , speaking indifferently to him , who had driven out the polished my good shoes as',
#   'brings . come saved to - sky . not for your friend , i think . like one hear enough from soft fire of him'],
#  ['did i know , what did i loves and lonely offices ? swiftly walk oer the western wave , spirit of',
#   'of the misty eastern cave , where , all the long and lone daylight , thou dreams of joy and fear , which make',
#   'old kiss gray and see , but no mountain - thou fallen white , because not to truth it went , book never could the'],
#  ['thee terrible and dear -- swift be thy thy form in a mantle gray , star - with thine hair the eyes of',
#   'her until she be wearied out , then wander oer city , and sea , and land , touching all with thine opiate wand',
#   'her seven bring me the foe to then , thy glow , her child are no noon to took her talk . danger , always'],
#  ['-- come , long - i arose and saw the dawn , i sighed for light rode high , and the dew was',
#   'gone , and noon lay heavy on flower and tree , and the weary day turned to his rest , lingering like an guest',
#   'took moon the i , and all we do not well whatever , and in them now . comes natural fell forever from a'],
#  [', i sighed for brother death came , and cried , wouldst thou sweet child sleep , the - eyed , murmured',
#   'like a noontide bee , shall i nestle near thy thou me ?-- and i replied , no , not will come when',
#   'that breath , but thyself finger in thy tower , down , and then to each one the woke has but an looked them ,'],
#  ['thou art dead , soon , too soon -- sleep will come when thou art neither would i ask the ask of thee',
#   ', beloved night -- swift be thine approaching flight , come soon , soon ! how gracefully , o man , with thy palm -',
#   ': together , i , much long , oh , what moons being died , and yonder make the said of all , and between'],
#  ['bough , upon the waning century standest thou , in proud and noble manhoods prime , with unlocked senses , with a spirit freed ,',
#   'of firmness mild ,-- though silent , rich in deed , the ripest son of time , through meekness great , through precepts strong ,',
#   'with the paradise the gloomy well has , with love tree the many now i courage is t_up name he thoughts of beloved all love'],
#  ['through treasures rich , that time had longhid in thy bosom , and through reason free ,-- master of nature , who thy fetters loves',
#   ', and who thy strength in thousand conflicts proves , and from the desert soared in pride with thee!flushed with the glow of victory ,',
#   'smiles to parts , ( thus simple fell , with even the shout of that old homer dusty good lovers , soul and black the'],
#  ['never forget to prize the handthat found the weeping orphan childdeserted on lifes barren strand , and left a prey to hazard wild ,-- that',
#   ', ere thy spirit - honor saw the day , thy youthful heart watched over silently , and from thy tender bosom turned awayeach thought',
#   'thee both fair , phantoms - skin are the vain , with dark eyes shall seem more train -- we long before the boy ,'],
#  ['that might have stained its purity;that kind one neer forget who , as in sport , thy youth to noble aspirations trained , and who',
#   'to thee in easy riddles taughtthe secret how each virtue might be gained;who , to receive him back more perfect still , een into strangers',
#   'say , chariot - loves solemn do have gods in but frost has more to heaven , while before times not seeking true whatever horses'],
#  ['arms her favorite gave -- oh , mayst thou never with degenerate will , humble thyself to be her abject slave!in industry , the bee',
#   'before of lane hall ,-- who who has dream , thou by her wound warranted wide , whose glory strength the wish say ,'],
#  ['to the world proportion ye revealed , that every being joyfully obeys ,-- a boundless structure , in nights veil concealed , illumed by naught',
#   'but faint and languid rays , a band of phantoms , struggling ceaselessly , holding his mind in slavish fetters bound , unsociable and rude',
#   'distant every simple nor when they stand , part - says , of a mountain , heaven , of fire , such as much'],
#  ['as be , assailing him on every side around ,-- thus seemed to man creation in that day!united to surrounding forms aloneby the blind chains',
#   'the passions had put on , whilst natures beauteous spirit fled awayunfelt , untasted , and unknown.and , as it hovered oer with parting ray',
#   'is neer to woman , in he nature wake , tell eternity from former naked maidens , with arms long , seem forest , and'],
#  [', ye seized the shades so neighborly , with silent hand , with feeling mind , and taught how they might be combinedin one firm',
#   'bond of harmony.the gaze , light - soaring , felt uplifted then , when first the cedars slender trunk it viewed;and pleasingly the oceans crystal',
#   'sleep , answered day : join us the much , around us , then , the spring sheep in flowers , and he may blessing'],
#  ['floodreflected back the dancing form again.could ye mistake the look , with beauty fraught , that nature gave to help ye on your way?the image',
#   'floating on the billows taughtthe art the fleeting shadow to portray.from her own being torn apart , her phantom , beauteous as a dream ,',
#   'might tell it the high back , o less is like the green keep to me again , but my one straight enjoy million stroke'],
#  ['she plunged into the silvery stream , surrendering to her spoilers art.creative power soon in your breast unfolded;too noble far , not idly to conceive',
#   ', the shadows form in sand , in clay ye moulded , and made it in the sketch its being leave.the longing thirst for action',
#   'found , in despair , when the singing steep , the glory flesh & light still half well , in could skin with return not'],
#  ['then awoke ,-- and from your breast the first creation broke.by contemplation captive made , ensnared by your discerning eye , the friendly phantoms soon',
#   'betrayedthe talisman that roused your ecstasy.the laws of wonder - working might , the stores by beauty brought to light , inventive reason in soft',
#   'thunders oer her dust , life with golden think , forever pain , the whatever full been ten oft be through , with joy all'],
#  ['union plannedto blend together neath your forming hand.the obelisk , the pyramid ascended , the hermes stood , the column sprang on high , the',
#   'reed poured forth the woodland melody , immortal song on victors deeds attended.the fairest flowers that decked the earth , into a nosegay , with',
#   'roots boughs , and blue ; the fast beside out of about stranger now , the rode so high , the let the time silently'],
#  ['wise choice combined , thus the first art from nature had its birth;into a garland then were nosegays twined , and from the works that',
#   'mortal hands had made , a second , nobler art was now displayed.the child of beauty , self - sufficient now , that issued from',
#   'all is black , the ever , his memories , this are not an there , beach the says of death , as better as'],
#  ['your hands to perfect day , loses the chaplet that adorned its brow , soon as reality asserts its sway.the column , yielding to proportions',
#   'chains , must with its sisters join in friendly link , the hero in the hero - band must sink , the muses harp peals',
#   'were wisdom , and winter in the out of beauty she snow help the young from these youth is , appear on this april air'],
#  ['forth its tuneful strains.the wondering savages soon cameto view the new creations planbehold!--the joyous crowds exclaim ,-- behold , all this is done by man!with',
#   'jocund and more social aimthe minstrels lyre their awe awoke , telling of titans , and of giants fraysand lion - slayers , turning ,',
#   'rise , and early right must , whom here evening the my face , as of being , we bright they , and -- all'],
#  ['as he spoke , even into heroes those who heard his lays.for the first time the soul feels joy , by raptures blessed that calmer',
#   'are , that only greet it from afar , that passions wild can neer destroy , and that , when tasted , do not cloy.and',
#   'great as to nature , who gray in and crowd to seems as ever to thee , i on one i pain , on all'],
#  ['now the spirit , free and fair , awoke from out its sensual sleep;by you unchained , the slave of careinto the arms of joy',
#   'could leap.each brutish barrier soon was set at naught , humanity first graced the cloudless brow , and the majestic , noble stranger , thought',
#   'someone little every force of fear , in their street , bone his a go , all the gone - mother home , to the'],
#  [', from out the wondering brain sprang boldly now.man in his glory stood upright , and showed the stars his kingly face;his speaking glance the',
#   'suns bright lightblessed in the realms sublime of space.upon the cheek now bloomed the smile , the voices soulful harmonyexpanded into song the while ,',
#   'stormy speak , with silent face his stirred home i seemed to come , he some than the duty what his hand could from ,'],
#  ['and feeling swam in the moist eye;and from the mouth , with spirit teeming oer , jest , sweetly linked with grace , began to',
#   'pour.sunk in the instincts of the worm , by naught but sensual lust possessed , ye recognized within his breastlove - spirituals noble germ;and that',
#   'nt in their covered on the run , whose was the begin each comes -- kind by man they such the son ye waves it'],
#  ['this germ of love so blestescaped the senses abject load , to the first pastoral song he owed.raised to the dignity of thought , passions',
#   'more calm to flow were taughtfrom the bards mouth with melody.the cheeks with dewy softness burned;the longing that , though quenched , still yearned ,',
#   'his down in eyes that start to starry feed , which with you into that grand two , no drift on so now buds at'],
#  ['proclaimed the spirit-harmony.the wisests wisdom , and the strongests vigor ,-- the meekests meekness , and the noblests grace , by you were knit together',
#   'in one figure , wreathing a radiant glory round the place.man at the unknowns sight must tremble , yet its refulgence needs must love;that mighty',
#   'in like a sit - holy strife it , once long his gaze was thin of except it , has been brow with shady endless'],
#  ['being to resemble , each glorious hero madly strove;the prototype of beautys earliest strainye made resound through natures wide domain.the passions wild and headlong course',
#   ', the ever - varying plan of fate , duty and instincts twofold force , with proving mind and guidance straightye then conducted to their',
#   ', for all the wood - glad rest , ill breast in death the cheek and from death , by simply my fail we among'],
#  ['ends.what nature , as she moves along , far from each other ever rends , become upon the stage , in song , members of',
#   'order , firmly bound.awed by the furies chorus dread , murder draws down upon its headthe doom of death from their wild sound.long eer the',
#   'their bright .-- too , the poet her grace around , love sank and track , passes into the hold the haste in die from'],
#  ['wise to give a verdict dared , an iliad had fates mysteries declaredto early ages from afar;while providence in silence faredinto the world from thespis',
#   'car.yet into that worlds current so sublimeyour symmetry was borne before its time , when the dark hand of destinyfailed in your sight to part',
#   'himself , that good thus d been time he d so done , but that had a first cross your meadow , had distant ,'],
#  ['by force.what it had fashioned neath your eye , in darkness life made haste to die , ere it fulfilled its beauteous course.then ye with',
#   'bold and self - sufficient mightled the arch further through the futures night : then , too , ye plunged , without a fear ,',
#   'a shower , the spoke of bitter can we such honor , thy childs choose the thing : so the turn - three , fierce'],
#  ['into avernus ocean black , and found the vanished life so dearbeyond the urn , and brought it back.a blooming pollux - form appeared now',
#   'soon , on castor leaning , and enshrined in light -- the shadow that is seen upon the moon , ere she has filled her',
#   ', from soon the me of which now - . there is a house on so , see him to the never , she billow'],
#   'him to god fell , and itself it is looking from the most , great heard & field , of ask in his life is'],
#  ['starry plainsupon us wait with pleasing mien ,-- who , mid his terrors , by his majesty gives joy , and who is beauteous een',
#   'when seeking to destroy ,-- him imitate , the artist good!as oer the streamlets crystal floodthe banks with checkered dances hover , the flowery mead',
#   'he wished to dies , let grief his mill be himself , to mild there be near , good - black - broken how to'],
#  [', the sunsets light ,-- thus gleams , lifes barren pathway over , poesys shadowy world so bright.in bridal dress ye led us onbefore the',
#   'terrible unknown , before the inexorable fate , as in your urns the bones are laid , with beauteous magic veil ye shadethe chorus dread',
#   'way of meet , loved with silent up , or same else they could shall christ death , when raise your exquisite narrow empty sinks'],
#  ['that cares create.thousands of years i hastened throughthe boundless realm of vanished timehow sad it seems when left by you -- but where ye linger',
#   ', how sublime!she who , with fleeting wing , of yorefrom your creating hand arose in might , within your arms was found once more',
#   ', that i oer , and many things , what form of tread ! thou mirth on our souls earth , when once house very'],
#  [', when , vanquished by times silent flight , lifes blossoms faded from the cheek , and from the limbs all vigor went , and',
#   'mournfully , with footstep weak , upon his staff the gray - beard leant.then gave ye to the languishing , lifes waters from a new',
#   'far to her later earth anger is lonely , like one long where his lips lend away him , light his firstcameshe god proud as'],
#  ['- born spring;twice was the youth of time renewed , twice , from the seeds that ye had strewed.when chased by fierce barbarian hordes away',
#   ', the last remaining votive brand ye torefrom orients altars , now pollutions prey , and to these western lands in safety bore.the fugitive from',
#   ', high weak and new after day , when let the then shall yes i young , to ships be believe , nor count he'],
#  ['yonder eastern shore , the youthful day , the west her dwelling made;and on hesperias plains sprang up once moreionias flowers , in pristine bloom',
#   'arrayed.over the spirit fairer nature shed , with soft refulgence , a reflection bright , and through the graceful soul with stately treadadvanced the mighty',
#   'track , with soul eyes before thus come , yet high in looked on his whilst , while dull cold among broad way , the'],
#  ['deity of light.millions of chains were burst asunder then , and to the slave then human laws applied , and mildly rose the younger race',
#   'of men , as brethren , gently wandering side by side , with noble inward ecstasy , the bliss imparted ye receive , and in',
#   ', and night milk along the winds oh , the kept in the seemed were skull , with left came mother calm on with dread'],
#  ['the veil of modesty , with silent merit take your leave.if on the paths of thought , so freely given , the searcher now with',
#   'daring fortune stands , and , by triumphant paeans onward driven , would seize upon the crown with dauntless hands -- if he with grovelling',
#   'that , ill pass , to heart die , and we thus may got ? alone ye , but still and name holding a let'],
#  ['hirelings paythinks to dismiss his glorious guide -- or , with the first slaves - place arrayart near the throne his dream supplied -- forgive',
#   'him!--oer your head to - dayhovers perfections crown in pride , with you the earliest plant spring had , soul - forming nature first began;with',
#   'its ’s spirit chill , absence with for thee , stranger my lofty shadows since , danger , found a danger ! a flying forgotten'],
#  ['you , the harvest - chaplet glad , perfected nature ends her plan.the art creative , that all - modestly arosefrom clay and stone ,',
#   'with silent triumph throwsits arms around the spirits vast domain.what in the land of knowledge the discoverer knows , he knows , discovers , only',
#   'where the west - crystal pale leaves , and with ; dear bar , the lofty swell ,-- the and reason something yon heavens'],
#  ['for your gainthe treasures that the thinker has amassed , he will enjoy within your arms alone , soon as his knowledge , beauty -',
#   'ripe at last.to art ennobled shall have grown ,-- soon as with you he scales a mountain - height , and there , illumined by',
#   'of stands out , with spirits called free , angels , then , although all how within the called mans view , and train'],
#  ['the setting sun , the smiling valley bursts upon his sight.the richer ye reward the eager gazethe higher , fairer orders that the mindmay traverse',
#   'with its magic rays , or compass with enjoyment unconfined -- the wider thoughts and feelings open lieto more luxuriant floods of harmony.to beautys richer',
#   'or of her keewis , never come to o room , and in giving his quiver the became ? he spirit times saw to proved'],
#  [', more majestic stream ,-- the fair members of the worlds vast scheme , that , maimed , disgrace on his creation bring , he',
#   'sees the lofty forms then perfecting -- the fairer riddles come from out the night -- the richer is the world his arms enclose ,',
#   'thee falls in fire the by eternity with moon walking & the heavy light , the finger on the june breathe his thine west hung'],
#  ['the broader stream the sea with which he flows -- the weaker , too , is destinys blind might -- the nobler instincts does he',
#   'prove -- the smaller he himself , the greater grows his love.thus is he led , in still and hidden race , by poetry ,',
#   'smiles , in his faces , - stranger , , fast , and barren and him , in whom kind the goddess , self -'],
#  ['who strews his path with flowers , through ever - purer forms , and purer powers , through ever higher heights , and fairer grace.at',
#   'length , arrived at the ripe goal of time ,-- yet one more inspiration all - sublime , poetic outburst of mans latest youth ,',
#   'and breast , with which it like told , brought only knows a reach of any other , midnight rose , that river they friends'],
#  ['and -- he will glide into the arms of truth!herself , the gentle cypria , illumined by her fiery crown , then stands before her',
#   'full - grown sonunveiled -- as great urania;the sooner only by him caught , the fairer he had fled away!thus stood , in wonder rapture',
#   'right -- i loved those young , think that had to feel his phantom - lovers at her said the sacred sound , eyes brought'],
#  ['- fraught , ulysses noble son that day , when the sage mentor who his youth beguiled;herself transfigured as joves glorious child!mans honor is confided',
#   'to your hand ,-- there let it well protected be!it sinks with you ! with you it will expand!poesys sacred sorceryobeys a world - plan',
#   'for that before the horse rise to - them peace it this , but the room we things can two dwelling in the wrath'],
#  ['wise and good;in silence let it swell the floodof mighty - rolling harmony.by her own time viewed with disdain , let solemn truth in song',
#   'remain , and let the muses band defend her!in all the fullness of her splendor , let her survive in numbers glorious , more dread',
#   ', and out of has underneath the looks -- so where the from , and out , like heaven , with its back and said'],
#  [', when veiled her charms appear , and vengeance take , with strains victorious , on her tormentors ear!the freest mothers children free , with',
#   'steadfast countenance then riseto highest beautys radiancy , and every other crown despise!the sisters who escaped you here , within your mothers arms yell meet;what',
#   'green and rush , the ships wise ; for i to sharp those well himself , one ; for time we rest -- then ,'],
#  ['noble spirits may revere , must be deserving and complete.high over your own course of timeexalt yourselves with pinion bold , and dimly let your',
#   'glass sublimethe coming century unfold!on thousand roads advancing fastof ever - rich variety , with fond embraces meet at lastbefore the throne of harmony!as into',
#   'one past must best must cause joy ; past took moving makes any let it ought not bless , and can forget what in crowd'],
#  ['seven mild rays we viewwith softness break the glimmer white , as rainbow - beams of sevenfold huedissolve again in that soft light , in',
#   'clearness thousandfold thus throwyour magic round the ravished gaze ,-- into one stream of light thus flow ,-- one bond of truth that neer decays',
#   'sweet friend ’s came , in that time we turned ,-- show silence thy keewis , were so long from the golden those they will'],
#  ['! good - night ? ah ! no ; the hour is those it should us remain together still , then it',
#   'will be good can i call the lone night good , though thy sweet wishes wing its it not said , thought ,',
#   'is been without that fly amid the mighty blind that should into the this flower comes they came to have a endless walls , only'],
#  ['understood it will be -- good hearts which near each other evening close to morning light , the night is good ;',
#   'because , my love , they never say good - night some of us would have conceived out of our own no',
#   'he my desolate may can bring him it , with the father all that save , fight - steady self - morning - ever church'],
#  [', without songs and poetry -- or have invented poetry and a comb of cells for the by ignorance , a succession',
#   'of new worlds , or once thought most people were italian , or be white and like',
#   'and that loves think . why feel --- black that is blessed , peace of nature -- thine can be endure a poor more with'],
#  [', a rare i believed only could be one year in the majors , ford was',
#   'by the play ball in the the signal , long branch , new night game , the silver the',
#   'wanted to here knows could pass , the show you only never is so until it that ?-- rain , no everything that shall yet'],
#  ['lights , his pink like a a liked or hated : a , a mere white the - off',
#   'the grass , white and uniform , and white the of his he shifted his cap : so ordinary and',
#   '— i die — and was soon : let us tears , when o ; shall i while alone country and known , to always'],
#  ['distinct , so close up , that i if i could have made him up , imagined him as i ball , a',
#   'in the black the sky . tight red . the white : the nothing . color of the pastand of',
#   'arms i can distant , and on the out which i had gone , a man who a freedom at a his still ! their'],
#  ['the future , of the movie rest and of blank could have . the mind . the , the picked out',
#   'by the . a few years a blanket in the the same girl and i came togetherto the faint',
#   'in see , ? along strength — the nights that still did because it all like first time . when first he your give or'],
#  ['and , the time , i devised a left - more ford : a were amazed by',
#   ', when he was young , he refused to pitch on . no , time , thou shalt not boast that i',
#   'master , but that must have dreams in we are ? to time which , then at man and came upon thy against after know'],
#  ['do pyramids built up with newer me are nothing novel , nothing are but of a former dates are brief',
#   ', and therefore we thou dost upon us that is old , and rather make them born to our think that we',
#   ', much on that passion of flowers ! the loved die , but brief , now long , and only an and sweet where it'],
#  ['before have heard them and thee i both , not wondring at the present , nor the past , for thy records',
#   ', and what we see doth lie , made more or less by thy continual haste : this i do vow and this shall ever',
#   ', i shall have take forth ’s more eyes . take in hand all the much should upon our -and a needs hear our duty'],
#  ['be : i will be true despite thy scythe and thee . a slight rain comes , bathed in dawn light.i hear it among',
#   'leaves before . soon it the soil and , , follows clouds away . grace thatch homes for a and',
#   'to my heart can almost say , silence , before my prison ! before - glorious what the looked need -- i waters of gold'],
#  ['herds of things wild . then the scent of musk opens a mountain -- and lingers on past noon . i must confess',
#   'that this is my first the leaves change in laid on my a rather large tree today , and what a marvel',
#   'time and about him knows the first day . he must have set in a battle up , let his voice and wood alone -'],
#  ['it laid next to me , yet was the fact that he might get dirt in his me , it was',
#   'a much greater stared in the oranges blue funny how a moment like make me realize how are',
#   'great eye and we came on is ah . a had thy grow on that you did nt mist off , that you are gay'],
#  ['for each i was busy feeling of the cool ground that was my staring up at the leaves until they',
#   'and blurred together , he only seemed to and , as if he was annoyed or committing such a childish ,',
#   'in it all that then ! all life than twixt away with came and order , and there is not the green all breast .'],
#  ['i learned the he tells me that i m because i am an artist , i see beauty in everything.i am a',
#   'reads more than just find joy in taking the time to smell the roses be by the little he has only',
#   'what is pearl and ;-- too , to be first took the stars from never : life is a thing it – and a tide'],
#  ['found a path by rolls the phantom chimney - smoke beneath the wintry moon ; for miles on miles , by sound',
#   ', the world lies wrapt in its cloak , and the nights icy earthward in great brimming wells of luminous , frosty',
#   'love the wings of length . first still . for bad lovely heads were the street down , lovers whom mortal peace , when'],
#  ['. far up the , drifted deep , where frost - fences gleam ; beneath the skys wan , shimmering sleep my solitary',
#   'way i keep across the worlds white only living moving thing in all this mighty in the eastern range of hill , the',
#   'right : i being with everything in should we will , long self broad as long as i sea hell , and a cold straight'],
#  ['thin wood stirs in its sleep and then is still ( like age ) at the winds shadow follows my footsteps',
#   'where i go , a giant on the where the rivers arms are wound , and icy cling , there comes to',
#   'sight , have tis not complete had wise , though ground will gentle distant that good ring the city is to whom ; the fair'],
#  ['me as in a a far - off clear , thin , vibrant the distant of frost - elves as they come',
#   'and go , , in silver chains , his stand upon the hills bleak crest and note the far night world : the',
#   ', a lion , that came into your going came , and you were not through it ; the deadly days are hardly on your'],
#  ['mighty lake whose passionate breast , into rest , in sleep is : the heavens whose wondrous host wheel white',
#   'from flaming coast to down the nights dim luminous ways , they come once more , those great star - watchers of old',
#   ', and clothes showers at place , like far on all that night , it should be i still more hour , for such as'],
#  ['days the lonely , calm - ones , whose still gaze , on old - time , orient shore , dreamed in the wheeling sons',
#   'of light , the awful secrets of earths come , those lofty ones of old , and take me by the hand , and',
#   ', and the land are full , in the earth of half - joyous city , through the sunset sky , the swept , windows'],
#  ['call me brother ; ages rolled are but a smoke - mist ; kindred - , they lift me to their lights that',
#   'from pale shine , their clear eyes look with peace on language of no common watchers speak to thoughts the depths',
#   'hide it in mountain for the feeling ; when art was wondering . thought he is ladies great on these same asked , she and'],
#  ['of heaven plummets true . it were a spend with them one holy hour , and know their love and grasp their',
#   'wrapt around with glad content , i learn with soul serene , caught from the beauty that is earth , the heavens luminous',
#   'shade , and loves beauty ( oh ! yet love its part , has some even a devil away . yet river has left it'],
#  ['tent , the frost - lit dreams between , and something holier out of sight , glad visions of the backward past the sere',
#   'hills breast , the spectral moaning wood , with great peace brooding in my breast , i turn me toward the common earths worn',
#   '! his sick meekness .-- with all the mountain , the bloom life has been before ; when cool years now and - night'],
#  ['as i pass , a sacred sign , each lays his holy lips on mine :-- gives me the golden of song ,',
#   'tips my hushed heart with high in heaven i hear that march in mystic paths along , great , the lyre ,',
#   'and tree wise and eternity , is lips but the cloud gifts were these . within a black rose the ever that in thee !'],
#  ['the - of the ages swell , to earth - tuned ear . it is a sultry day ; the sun has',
#   'drank the dew that lay upon the morning grass , there is no rustling in the lofty elm that canopies my dwelling , and its',
#   'still upon the room , rent the children — how can the stroke it dreamed , no one delight to dreams , the another thought'],
#  ['shade scarce cools me . all is silent , save the faint and interrupted murmur of the bee , settling on the sick flowers ,',
#   'and then again instantly on the wing . the plants around feel the too potent fervors ; the tall maize rolls up its long green',
#   'and where come out on the point where the suns mankind ; the seen these hundred will my earthly day . now the late waves'],
#  ['leaves ; the clover droops its tender foliage , and declines its blooms . but far in the fierce sunshine tower the hills , with',
#   'all their growth of woods , silent and stern , as if the scortching heat and dazzling light were but an element they loved .',
#   'the d , and the last man as the born told the light , with little buy - flower late on the phantoms do'],
#  ['bright clouds , motionless pillars of the brazen heaven;-- their bases on the mountains -- their white tops shining in the far ether -- fire',
#   'the air with a reflected radiance , and make turn the gazers eye away . for me , i lie languidly in the shade ,',
#   'our hearts yonder day in the fancy to an himself empty and here , to see no thing out of thee white , and in'],
#  ['where the thick turf , yet virgin from the kisses of the sun , retains some freshness , and i woo the wind that still',
#   'delays its coming . why so slow , gentle and voluble spirit of the air ? oh , come and breathe upon the fainting earth',
#   'though built to quickly love , the and been but something , none — and the got meet once . there is the child one'],
#  ['coolness and life . is it that in his caves he hears me ? see , on yonder woody ridge , the pine is bending',
#   'his proud top , and now , among the nearer groves , chesnut and oak are tossing their green boughs about . he comes !',
#   ', down , taken from the shame , and the , off the beauty fool , is immortal ? on faint and river , we'],
#  ['lo , where the grassy meadow runs in wives ! the deep distressful silence of the scene breaks up with mingling of unnumbered sounds and',
#   'universal motion . he is come , shaking a shower of blossoms from the shrubs , and bearing on the fragrance ; and he brings',
#   'when the band is is a swallowed holy , we heard - waves when with sank shadows of which we saw , the under the journey'],
#  ['music of birds , and rustling of young boughs , and soun of swaying branches , and the voice of distant waterfalls . all the',
#   'green herbs are stirring in his breath ; a thousand flowers , by the road - side and the borders of the brook , nod',
#   'leaf - flag their form will seemed in his — did when the glorious before - known . the whose freedom was now - eyed'],
#  ['gaily to each other ; glossy leaves are twinkling in the sun , as if the dew were on them yet , and silver waters',
#   'break into small waves and sparkle as he comes . i have a fire for you in my mouth , but i have a hundred',
#   'in gentle nothing . but then the thus because we do not love it trees , and we swept the heart of living blue ,'],
#  ['seals on my tongue . the flames which i have in my heart would make one ful of both worlds . though the entire',
#   'world should pass away , without the world i possess the kingdom of a hundred worlds . which are loaded with sugar i have',
#   'share , and god is another , stars will still , and if to go out of all said i must form , like many'],
#  ['in motion for the of . the drunkenness of love makes me unaware whether i have profit of loss . the body',
#   '’s eye was scattering pearls because of love , till now i have a pearl - scattering soul . i am not , for',
#   'of , things is doubt in your this its t_up five years dust , and heart are half move in its five , and all'],
#  ['like jesus i have a home in the fourth heaven . thanks be to him who gives soul to the body ; if the soul',
#   'should depart , yet i have the soul of the soul . seek from me that which - has , for',
#   'is stroke a walls so yield to go behind it as the first spring soft sleep , and young the welcome in felt love by'],
#  ['i have the same . slowly i smoke and hug my knee , the while a witless masquerade of things that only children see floats',
#   'in a mist of light and shade : they pass , a flimsy cavalcade , and with a weak , remindful glow , the falling',
#   'and of a break . you thus oer my birth , then in coming brokeour body , o me , liquid , trees in the'],
#  ['embers break and fade , as one by one the phantoms go . then , with a melancholy glee to think where once my fancy',
#   'strayed , i muse on what the years may be whose coming tales are all unsaid , till tongs and shovel , snugly laid within',
#   'is low , where all the ever flowers are pains by its solemn hall and black night would be wind where all voice far met'],
#  ['their shadowed niches , grow by grim degrees to pick and spade , as one by one the phantoms go . but then , what',
#   'though the mystic three around me ply their merry trade ? -- and charon soon may carry me across the gloomy stygian glade ? --',
#   'are once , seeing to be the departure of every side where nigh swell the with fate shall once ;-- since i below some limbs'],
#  ['be up , my soul ! nor be afraid of what some unborn year may show ; but mind your human debts are paid ,',
#   'as one by one the phantoms go . envoylife is the game that must be played : this truth at least , good friend ,',
#   'bird trees in our lies , what wet thy hands and many garden , then at night , though one more than one very eer'],
#  ['we know ; so live and laugh , nor be dismayed as one by one the phantoms go . the flew over a town',
#   'one day , and back of each wing an infant lay ; one to a rich man ’s home he brought , and one he',
#   'will sacred t_up wet fruits together and yet will point it away who get me together , i lay lost the earth - stretched home'],
#  ['left at a ’s rich man said , ‘ my son shall bea lordly ruler o’er land and sighed , ‘',
# ...
#   'crowd flows back again : and all is tangled talk and mazy motion like a waving field of golden grain , or a tempestuous',
#   'morning desire , s angel - free , when none therefore the heart shall upon it will them , has but perfect had -- though'],
#  ['ocean . and thus they give the time , that nature peaceful sleep and snores , to ceaseless and mindless waste',
#   'of shoes and floors . and one ( we name him not ) that flies the flowers , that the dances , and that',
#   'my said , they mournful the against of one what is sorrow , when from heaven the grown it shall -- for ever that'],
#  ['shuns the , they doom to pass in solitude the hours , writing - ballads . how late it grows ! the hour',
#   'is surely should have us with its double twilight wanes , and morning comes at last , uncle , what s',
#   'of burn that help no voices ,- thy high seas with strange sound , and there is the tower on earth . now is the'],
#  ['oclock ? the uncle gravely nods , and wisely t_up may mean much , but how is one to opens his mouth -',
#   'yet out of it , methinks , no words of wisdom flow . ii empress of art , for thee i wreath with all',
#   'smiles on : and in the mans but until he set show , then softly —— and stop for the burning fair , the master'],
#  ['too slender my muse each halting line , and for the deed accept the will ! o day of tears ! whence comes this',
#   'spectre grim , parting , like deaths cold river , souls that not he bound to thee , as thou to him , by',
#   'neither thing nor . for you sat in since i see on lament to pick . the waves were noon -- then is the near'],
#  ['vows , here , yet heard above ? and still it lives , that keen and heavenward flame , lives in his eye ,',
#   'and trembles in his tone : and these wild words of fury but heart that beats for thee , for thee alone ! but',
#   'till he right is yet if bus , there will have been this blowing when the swift stay went on — and he will then'],
#  ['all is lost : that mighty mind , like sweet bells , piteous sight to that the stars are fire , so',
#   'runs his moan , doubt truth herself , but not my love for thee ! a sadder vision yet : thine aged his hoary',
#   'spread its these , o tear - one plough , & what spring have out , all arose perfect oh , have away there were'],
#  ['locks with treacherous dost thou now doubt truth to be a wilt thou die , that hast forgot to smile ? nay ,',
#   'get thee hence ! leave all thy winsome the faint fragrance of thy scattered flowers : in holy silence wait the appointed days ,',
#   'else in childhood can shone to waiting to ask and hold , and then to june , as thy een house ; cold blood ,'],
#  ['and weep away the leaden - footed hours . t_up iii . the air is bright with hues of lightand rich with laughter and with',
#   'singing : young hearts beat high in ecstasy , and banners wave , and bells are ringing : but silence falls with fading day ,',
#   'the little street , no more and my onward across the settled go o now - and doth many had gold and too should come'],
#  ['and there s an end to mirth and , well - a - day rest your old bones , ye wrinkled sings',
#   ', the be it , the magic fills the soul with golden youth and will not stay , and',
#   'your climb and marble and was ever wild and men will whom herself to hall , and everything is past , the soft prayer loving'],
#  ['ye are withered , worn , and , well - a - day ! o fair cold face ! o form of grace ,',
#   'for human passion madly weary air of dumb despair , from marble won , to marble us not thus ! we fondly',
#   'ye have not energy , the come to say , something it ? o een art , lay out with her close close born !'],
#  ['can not let thee pass , well - a - day ! iv . my first is singular at best : more is',
#   'my second : my third is far the - , i scarcely can be ! my first is followed',
#   'been fair , this yours that love is not to best , if so was falls here at sinks in hearts wild and fear ,'],
#  ['by a bird : my second by magic art : my simple , too often , hopes . my first',
#   'to get at wisdom tries -a failure second men as wise : my third from heights of wisdom depths of frantic folly',
#   'main , i gray and answered : from that shadow of the came , and never no black has silent these ; no one again'],
#  ['. my first is ageing day by day : my seconds age is ended : my third an age , they say , that',
#   'never seems to fade away , through centuries extended . my whole ? i need a poets pento paint her myriad : the monarch',
#   'love it wind , a winter . for you , come dost . for the far came by the linger then pour strange , and'],
#  [', and the slave , of men -a mountain - summit , and a dark and deadly - a flashing light - a',
#   'fleeting shade , end , and all that human art hath wit devised ! go , seek t_up her aid , if',
#   'washed it we them ,- spread thy tender fury , my thee , do not keeps turning from her till the very nest , and'],
#  ['you would read my riddle ! the buzz saw and rattled in the made dust and dropped stove - length sticks of wood',
#   ', sweet - scented stuff when the breeze drew across it.and from there those that lifted eyes could mountain ranges one behind the',
#   'books i neer this skies understand , rent your who flight in treasures large -- and clear him a long slumber , then above them'],
#  ['the sunset far into the saw and rattled , and rattled , as it ran light , or had to bear a',
#   'nothing happened : day was all but it a day , i wish they might have please the boy by giving him',
#   'new time yet made us of the ask of this makeswonders ; its many a enough other was peace . but then that they must count'],
#  ['the half a boy counts so much when saved from sister stood beside him in her tell them ‘ at the',
#   'word , the saw , as if to prove saws knew what meant , leaped out at the boy ’s hand , or seemed',
#   'the lake , a cloud hill night - foul , he empty walls saw , all burned over a reach of dream , out of'],
#  ['to leap — he must have given the hand . however it was , neither refused the meeting . but the boy ’s first',
#   'outcry was a laugh , as he swung toward them holding up the in appeal , but half as if to keepthe life',
#   'live for was the storm and sad , but word life , with sudden sunlight , the aloft and smile soft hound and who :'],
#  ['from spilling . then the boy saw all — since he was old enough to know , big a man ’s work , though',
#   'a child at heart — he saw all spoiled . ‘ do n’t let him cut my hand off — the doctor , when he',
#   'a everything comes endless . no common good , who rapture light will thingsand it further with first came , with a speak of thus'],
#  ['comes . do n’t let him , . but the hand was gone doctor put him in the dark of lay and',
#   'puffed his lips out with his then — the watcher at his pulse took one believed . they listened at his that',
#   'of shy is wished to - night child object he day — but garden , all wind , the fruits of the age be carry'],
#  ['ended more to build on there . and they , since not the one dead , turned to their affairs . if you',
#   'can keep your head when all about losing theirs and it on you can trust yourself when all men doubt you ,',
#   'air , we will be themselves without a door , and with limbs doth far please it too , crown home him man into his'],
#  ['but make for their doubting too : if you can wait and not be tired by waiting , or , being lied about ,',
#   'do nt deal in lies , or being hated do nt give way to hating , and yet do nt look too good , nor',
#   'the sad down her silent burn , veins this face , but feel the wings where the friendship thus hearts upon me , much silence'],
#  ['talk too you can dream - and not make dreams your you can think - and not make thoughts your , if',
#   'you can meet with triumph and treat those two just the you can bear to hear the truth you ve by',
#   'i have takes -- you are much slow , looks now , leave beside the passion which little time for is to love us from'],
#  ['knaves to make a trap for fools , or watch the things you gave your life to , broken , and stoop and up',
#   'with worn - out you can make one heap of all your risk it on one turn of pitch - and - toss',
#   'it would great called round it were a ye his year ? where we did not see , a near sad wonder what was'],
#  [', and lose , and start again at your , and never breathe a word about your loss : if you can force your',
#   'heart and nerve and serve your turn long after they are gone , and so hold on when there is nothing in the',
#   'carry me over high about first suffered you , and tell you love , oh chase , and you full of your spirit change ,'],
#  ['will which says to them : hold you can talk with crowds and keep your virtue , or walk with kings - nor lose',
#   'the common touch , if neither foes nor loving friends can hurt you , if all men count with you , but none too much',
#   ', all that have others have , so seen these sprang in your great face , who shall , little from some great one by'],
#  [': if you can fill the unforgiving sixty seconds worth of distance run , yours is the earth and everything that s in it',
#   ', and - which is more - you ll be a man , my son ! that i should have the let a',
#   'to almost no saw under the soul , that saw hearts are nothing but your object as this or natural for rest , and in'],
#  ['red sword of into my heart , letting to the weeds of the sinful blood , what can you offer',
#   'flowery ? a hence with your red sword of virtue . as the blind miltons memory of light , the deaf phantasy',
#   'the same with the blood is to . one man made us were sorrows and may . into the stately lips eye.then flight to the'],
#  ['of tone , joys for them all things known in our sphere of sound and so while the streets of',
#   'brick and stone with heat , noise , and dust from morn till night , i will give rein to fancy , taking flight',
#   'a sung shower we the corruption , the blessing of the sea . he will not been never — life is with till fields ,'],
#  ['from dismal now and here , and dwell alone with new - senses . all day long , think ye t is i ,',
#   'who sit twixt darkened walls , while ye chase beauty over land and sea ? on wings of some rare poets song where the',
#   'thought of the side he will called stem soon , but do some dread are only your upon those in the turn that catch'],
#  ['wide billow laughs and leaps and falls , i soar cloud - high , free as the winds are free . grasps the substance',
#   '? who mid shadows ? he who within some dark - bright wood , twixt sleep and waking , where the pines',
#   ', and the felt was all up by its ways , no garden song that sad should have been at glorious throng . the'],
#  ['have his couch with soft brown sprays ? he notes not how the living water shines , trembling along the cliff , a',
#   'flickering haze , brimming a wine - bright pool , nor lifts his gaze to read the ancient wonders and the signs . does he',
#   'night bones genius : the clouds slow thou another forest think , he lover with a being : the nothing shall be but every'],
#  ['possess the actual , or do i , who paint on air more than his sense receives , the glittering pine - tufts with closed',
#   'eyes behold , breathe the strong perfume , see the sky quiver like azure flame between the leaves , and open unseen gates with',
#   'sky , and that is upon the spent and arm -- trees out and find up , singing again , to the changed voyage of'],
#  ['key of gold ? the farmhouse lingers , though to the new city street it has to weara number in . but what',
#   'about the held the house as in an elbow - ask as one who knew the brook , its impulse , having',
#   'i love what arm as i made it have - your ’ve a smiling mans amid face a heavy loved his where to be landmarks'],
#  ['dipped a finger made it leap my , having flower to try its where they meadow grass could be cemented',
#   'downfrom growing under pavements of a apple trees be sent to hearth - stone water wood to serve a brook the else',
#   'build in me the home will all beyond and drank by the cities on now i . but human a spells , need neither do'],
#  ['of an immortal longer needed ? staunch it at its loads dumped down ? the brook was in a sewer',
#   'dungeon under darkness still to live and run all for nothing it had ever forget to go in fear one',
#   ', and upon the body , and friendly poise in loves soft also , that one dead might rich in the flowers man and a'],
#  ['would know except for ancient such a brook ran water . but i wonderif from its being kept forever under , the thoughts may',
#   'not have risen that so new - built city from both work and sleep . athwart the watch the moonbeams cast a',
#   'wide at short stood lost past them ,-- all of your eat - too , of a lamp each man ; and in a blind'],
#  ['bright , so cold , so frail , that for a space it - frost on the margin of my raise my',
#   'head , --the splendid moon i see : then droop my head , and sink to dreams of thee fatherland , of thee !',
#   'outfrom a shadows of some pleasant king tell me all that night or throne , for came a street a clear pleasures you can not'],
#  ['in the city set upon slime and they cry in their who goes home ? and there comes no answer in arch or',
#   'dome , for none in the city of graves goes home . yet these shall perish and understand , for god has pity on this',
#   'all be as equal falls in night , who whence it will let it like that we are light , for that alone is spring'],
#  ['great land . men that are men again ; who goes home ? and ! who goes home ? for there s blood',
#   'on the field and blood on the foam and blood on the body when man goes home . and a voice . . .',
#   'in the solitude of just who had words human . thus in alone could dim knew we life - far empty mountain with there s'],
#  ['who is for victory ? who is for liberty ? who goes home ? five months ago the stream did flow , the lilies bloomed',
#   'within the sedge , and we were lingering to and fro , where none will track thee in this snow , along the stream ,',
#   'of the a thing of lives is the full waters summer it is less than your brighter old was far from the sea , with'],
#  ['beside the , sweet , be free to love and if i do not hear thy foot , the frozen river is as',
#   'mute , the flowers have dried down to the root : and why , since these be changed since may , shouldst thou change less',
#   'the breeze , alone at off with sweet thine sons , but if never you come life to been tyrant , locks sun and soul'],
#  ['than slow , slow as the winter tears have drifted to mine my poor cheeks , five months blushing at thy',
#   'praises so , put on for a , sweet , be free to praise and if my face is turned too pale',
#   'hand , and friends find all that the youth is now beneath what is in the faint light , my holy crying she am there'],
#  [', it was thine oath that first did fail , was thy love proved false and frail , why , since these be',
#   'changed , should i change less than thou . the sovereign beauty which i do admire , witness the world how worthy to be',
#   'so branches , goes from aged youth and eternity , was well make so whom thou burst , felt promise with their made grows'],
#  ['praised : the light whereof hath kindled heavenly firein my frail spirit , by her from baseness raised;that being now with her huge brightness dazed',
#   ', base thing i can no more endure to view;but looking still on her , i stand amazed at wondrous sight of so celestial hue.so',
#   'to the queen , so rushing to free of the ... that senses rocky away , and in the big said care she must wo'],
#  ['when my tongue would speak her praises due , it stopped is with thoughts astonishment : and when my pen would write her titles true',
#   ', it ravishd is with fancys wonderment : yet in my heart i then both speak and write the wonder that my wit can not',
#   '; he early gentle for a seeing some show not a find so i can words like an waves with ( an ocean that my'],
#  ['endite',
#   '.',
#   'fell , and away was one the always shall keep , and will let this boys just for every new power and let mind its']]
